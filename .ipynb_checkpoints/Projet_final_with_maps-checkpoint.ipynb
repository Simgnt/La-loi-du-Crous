# %%
import pandas as pd 
import geopandas as gpd 
import nltk
nltk.download('punkt')
import contextily as ctx
import geoplot as gplt
import geoplot.crs as gcrs
import matplotlib.pyplot as plt
import folium
import numpy as np
import seaborn as sns
import altair as alt
# Out:
# [nltk_data] Downloading package punkt to /home/onyxia/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/mamba/share/proj failed

# %%
#!pip install geoplot
#!pip install contextily
#!pip install altair

# %% [markdown]
# # Part I : Obtention du dataframe
# ## 1.1.Récupération des loyers, des surfaces et de la localisation des résidences

# %%
df = pd.read_csv("fr_crous_logement_france_entiere.csv", sep =';')

# %%
from functions_for_data_cleaning import *

df = get_loyer(df)
df = get_surface(df)
df = get_localisation(df) 
df
# Out:
# [nltk_data] Downloading package punkt to /home/onyxia/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /home/onyxia/work/Immobilier-etudiant-/functions_for_data_cleaning.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Loyer"][j] = remove(df["Loyer"][j], 100, 1000)
# /home/onyxia/work/Immobilier-etudiant-/functions_for_data_cleaning.py:218: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Surface'][j] = remove(df['Surface'][j], 7, 100)
#       id                                              title  \
# 0    205                                   Résidence Vauban
# 1    207                 Résidence Le Square de l'Echiquier
# 2    214                       Résidence Les Bas Longchamps
# 3    225                                 Résidence de l’Ile
# 4    228                             Résidence La Pacaterie
# ..   ...                                                ...
# 783  349  Cité Grémillon (secteur d'Hérouville-Saint-Clair)
# 784  331                           Résidence Antide Janvier
# 785  335                         Résidence Jean Paul Sartre
# 786  416                                              Maret
# 787  420                                          Antipodes
#
#                                         short_desc                     zone  \
# 0                                       Guyancourt                 YVELINES
# 1                                   Cergy-Pontoise               VAL D'OISE
# 2                                          Bagneux           HAUTS DE SEINE
# 3                                 Bures-sur-Yvette                  ESSONNE
# 4                                            Orsay                  ESSONNE
# ..                                             ...                      ...
# 783                                            NaN   Herouville Saint Clair
# 784                    Centre ville, sur les quais  Besançon - Centre ville
# 785                                   Centre ville                  Belfort
# 786  Logements proposés : chambres traditionnelles             DIJON CENTRE
# 787   Logements proposés: appartements du T1 au T3             DIJON CAMPUS
#
#                                                  infos  \
# 0    Description La résidence est située au cœur de...
# 1    DescriptionRésidence universitaire nouvellemen...
# 2    Description Résidence universitaire située à p...
# 3    Description Résidence universitaire située à p...
# 4    Description Résidence universitaire longée par...
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784  Localisation :\r\n Au centre ville, à proximit...
# 785  Localisation :\r\n La résidence Sartre est sit...
# 786                                                NaN
# 787  La résidence compte 350 logements (du T1 au T3...
#
#                                               services  \
# 0    Laverie \r\n  Salles de travail \r\n  Salles d...
# 1    Wifi \r\n   Laverie \r\n  salle de sport \r\n ...
# 2    Laverie \r\n    Salles de travail et de détent...
# 3    Salles de détente, une avec télévision \r\n   ...
# 4    Salles de détente             (télévision, ate...
# ..                                                 ...
# 783                        Gratuits (Sauf € = Payants)
# 784        Wifi Inclus dans le loyerPoint restoParking
# 785                    LaverieParking fermé (15€/mois)
# 786  La Résidence universitaire Maret, située en pl...
# 787  La résidence bénéficie de cabines téléphonique...
#
#                                                contact  \
# 0    Résidence Vauban\r\n 1 boulevard d’Alembert782...
# 1    Résidence Le Square de l'échiquier\n9 square d...
# 2    Résidence de Bagneux /Les Bas de Longchamps\r\...
# 3    Résidence de l’Ile\n14 rue du Docteur Collé - ...
# 4    Résidence La Pacaterie\nBâtiment 499 - rue de ...
# ..                                                 ...
# 783  Cité Grémillon (Secteur d'Hérouville-Saint-Cla...
# 784  Résidence Antide Janvier \r\n 49 T1 et de 27 T...
# 785  Résidence Jean-Paul Sartre \r\n 130 T1, 11 T1 ...
# 786  Résidence MARET \r\n 3 rue du Docteur Maret \r...
# 787  Résidence ANTIPODES \r\n 24/32 rue Alain Savar...
#
#                                                address  \
# 0              1 boulevard d’Alembert 78280 Guyancourt
# 1         9 square de l'échiquier 95800 Cergy-Pontoise
# 2                  2 rue Abraham Lincoln 92220 Bagneux
# 3    14 rue du Docteur Collé - bâtiment 227 du camp...
# 4       Bâtiment 499 - rue de la Pacaterie 91400 Orsay
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784                6 rue Antide Janvier 25000 Besançon
# 785                   Rue Gaston Deferre 90000 Belfort
# 786                3 rue du Docteur Maret  21000 Dijon
# 787                24/32 rue Alain Savary  21000 Dijon
#
#                                             mail  \
# 0           residence.vauban@crous-versailles.fr
# 1          residence.lacroix@crous-versailles.fr
# 2          residence.bagneux@crous-versailles.fr
# 3              residence.ile@crous-versailles.fr
# 4        residence.pacaterie@crous-versailles.fr
# ..                                           ...
# 783                herouville@crous-normandie.fr
# 784  pole-hebergement-besancon@crous-besancon.fr
# 785            pole-hebergement-nfc@crous-bfc.fr
# 786                                          NaN
# 787                                          NaN
#
#                                phone  ... Max Loyer Min Loyer  Mean Loyer  \
# 0                     01 80 73 04 00  ...    537.00    333.00  435.000000
# 1                     01 30 30 38 53  ...    334.00    334.00  334.000000
# 2                     01 86 63 00 90  ...    359.00    332.00  345.500000
# 3                     01 69 07 68 96  ...    362.00    362.00  362.000000
# 4                     01 69 15 75 98  ...    154.00    154.00  154.000000
# ..                               ...  ...       ...       ...         ...
# 783                   02 31 47 61 23  ...    556.14    249.85  416.648333
# 784                   03 81 48 47 50  ...    523.00    347.00  457.333333
# 785  03.84.21.95.37 - 06.48.41.76.36  ...    586.00    280.00  403.571429
# 786                   03.45.34.84.57  ...       NaN       NaN         NaN
# 787                   03.45.34.84.81  ...       NaN       NaN         NaN
#
#                                  Surface Max Surface Min Surface Mean Surface  \
# 0                                     []         NaN         NaN          NaN
# 1                                     []         NaN         NaN          NaN
# 2                                 [28.0]        28.0        28.0    28.000000
# 3                                 [18.0]        18.0        18.0    18.000000
# 4                                     []         NaN         NaN          NaN
# ..                                   ...         ...         ...          ...
# 783  [9.0, 18.0, 30.0, 49.0, 65.0, 69.0]        69.0         9.0    40.000000
# 784                         [19.0, 35.3]        35.3        19.0    27.150000
# 785                   [18.0, 36.0, 51.5]        51.5        18.0    35.166667
# 786                                 None         NaN         NaN          NaN
# 787                                   []         NaN         NaN          NaN
#
#     Longitude   Latitude                   geometry
# 0    2.044151  48.779652   POINT (2.04415 48.77965)
# 1    2.026887  49.048298   POINT (2.02689 49.04830)
# 2    2.316971  48.790691   POINT (2.31697 48.79069)
# 3    2.157896  48.698803   POINT (2.15790 48.69880)
# 4    2.184678  48.701542   POINT (2.18468 48.70154)
# ..        ...        ...                        ...
# 783 -0.339214  49.203205  POINT (-0.33921 49.20321)
# 784  6.015343  47.236507   POINT (6.01534 47.23651)
# 785  6.853714  47.638988   POINT (6.85371 47.63899)
# 786  5.035332  47.322498   POINT (5.03533 47.32250)
# 787  5.072239  47.310177   POINT (5.07224 47.31018)
#
# [788 rows x 30 columns]

# %% [markdown]
# ## 1.2.Récupération des loyers privés des communes (avec la géolocalisation des communes)

# %%
df_private = pd.read_csv("https://www.data.gouv.fr/fr/datasets/r/8fac6fb7-cd07-4747-8e0b-b101c476f0da", encoding= 'unicode_escape', sep = ";")

# %% [markdown]
# On ne garde que le code INSEE, le nom de la ville et le loyer supérieur par m^2

# %%
df_private = df_private[["INSEE", "LIBGEO","upr.IPm2"]]

# %% [markdown]
# On renomme la colonne INSEE en codgeo pour pouvoir la merger avec la carte des contours des villes.

# %%
df_private.rename(columns = {'INSEE':'codgeo'}, inplace = True)

# %%
"""
On rajoute un 0 devant le code INSEE quand il ne fait que quatre chiffres (pour uniformiser avec l'autre base). 
"""
for i in range(0,df_private.shape[0]):
    if  len(df_private["codgeo"][i]) == 4: 
            df_private["codgeo"][i] = "0" +  df_private["codgeo"][i]

# %%
df_private = df_private.set_index('codgeo') #on réindex le dataframe avec le code INSEE pour merger après.

# %% [markdown]
# On récuppère les contours géographique des communes.(prends du temps)

# %%
gdf_communes_boundaries = gpd.read_file("https://www.data.gouv.fr/fr/datasets/r/e9391593-fa95-4153-aabe-87ca84d197e9")

# %% [markdown]
# On ne garde que le code INSEE et les données polygoniales.

# %%
gdf_communes_boundaries.rename(columns = {'INSEE_COM':'codgeo'}, inplace = True)
gdf_communes_boundaries = gdf_communes_boundaries[["codgeo", "geometry"]]
gdf_communes_boundaries = gdf_communes_boundaries.set_index('codgeo')

# %% [markdown]
# On concatène les deux datafarmes

# %%
gdf_private = pd.concat([df_private,gdf_communes_boundaries], axis = 1, join = "inner")

# %% [markdown]
# ## 1.3. Jointures spatiales

# %%
#gdf_private['geometry'] = gdf_private['geometry'].apply(wkt.loads) #on transforme en format wkt (sinon ça ne marche pas)
gdf_private = gpd.GeoDataFrame(gdf_private)  #on transforme en geodataframe 
df = gpd.sjoin(df, gdf_private, how='left', op='within') #on réalise la jointure à gauche avec within 
#i.e si le point est dans le polynôme.
# Out:
# /opt/mamba/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3373: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /tmp/ipykernel_14186/2580680376.py:3: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   df = gpd.sjoin(df, gdf_private, how='left', op='within') #on réalise la jointure à gauche avec within

# %%
del df['index_right'] #on supprime l'index right pour la prochaine jointure
df
# Out:
#       id                                              title  \
# 0    205                                   Résidence Vauban
# 1    207                 Résidence Le Square de l'Echiquier
# 2    214                       Résidence Les Bas Longchamps
# 3    225                                 Résidence de l’Ile
# 4    228                             Résidence La Pacaterie
# ..   ...                                                ...
# 783  349  Cité Grémillon (secteur d'Hérouville-Saint-Clair)
# 784  331                           Résidence Antide Janvier
# 785  335                         Résidence Jean Paul Sartre
# 786  416                                              Maret
# 787  420                                          Antipodes
#
#                                         short_desc                     zone  \
# 0                                       Guyancourt                 YVELINES
# 1                                   Cergy-Pontoise               VAL D'OISE
# 2                                          Bagneux           HAUTS DE SEINE
# 3                                 Bures-sur-Yvette                  ESSONNE
# 4                                            Orsay                  ESSONNE
# ..                                             ...                      ...
# 783                                            NaN   Herouville Saint Clair
# 784                    Centre ville, sur les quais  Besançon - Centre ville
# 785                                   Centre ville                  Belfort
# 786  Logements proposés : chambres traditionnelles             DIJON CENTRE
# 787   Logements proposés: appartements du T1 au T3             DIJON CAMPUS
#
#                                                  infos  \
# 0    Description La résidence est située au cœur de...
# 1    DescriptionRésidence universitaire nouvellemen...
# 2    Description Résidence universitaire située à p...
# 3    Description Résidence universitaire située à p...
# 4    Description Résidence universitaire longée par...
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784  Localisation :\r\n Au centre ville, à proximit...
# 785  Localisation :\r\n La résidence Sartre est sit...
# 786                                                NaN
# 787  La résidence compte 350 logements (du T1 au T3...
#
#                                               services  \
# 0    Laverie \r\n  Salles de travail \r\n  Salles d...
# 1    Wifi \r\n   Laverie \r\n  salle de sport \r\n ...
# 2    Laverie \r\n    Salles de travail et de détent...
# 3    Salles de détente, une avec télévision \r\n   ...
# 4    Salles de détente             (télévision, ate...
# ..                                                 ...
# 783                        Gratuits (Sauf € = Payants)
# 784        Wifi Inclus dans le loyerPoint restoParking
# 785                    LaverieParking fermé (15€/mois)
# 786  La Résidence universitaire Maret, située en pl...
# 787  La résidence bénéficie de cabines téléphonique...
#
#                                                contact  \
# 0    Résidence Vauban\r\n 1 boulevard d’Alembert782...
# 1    Résidence Le Square de l'échiquier\n9 square d...
# 2    Résidence de Bagneux /Les Bas de Longchamps\r\...
# 3    Résidence de l’Ile\n14 rue du Docteur Collé - ...
# 4    Résidence La Pacaterie\nBâtiment 499 - rue de ...
# ..                                                 ...
# 783  Cité Grémillon (Secteur d'Hérouville-Saint-Cla...
# 784  Résidence Antide Janvier \r\n 49 T1 et de 27 T...
# 785  Résidence Jean-Paul Sartre \r\n 130 T1, 11 T1 ...
# 786  Résidence MARET \r\n 3 rue du Docteur Maret \r...
# 787  Résidence ANTIPODES \r\n 24/32 rue Alain Savar...
#
#                                                address  \
# 0              1 boulevard d’Alembert 78280 Guyancourt
# 1         9 square de l'échiquier 95800 Cergy-Pontoise
# 2                  2 rue Abraham Lincoln 92220 Bagneux
# 3    14 rue du Docteur Collé - bâtiment 227 du camp...
# 4       Bâtiment 499 - rue de la Pacaterie 91400 Orsay
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784                6 rue Antide Janvier 25000 Besançon
# 785                   Rue Gaston Deferre 90000 Belfort
# 786                3 rue du Docteur Maret  21000 Dijon
# 787                24/32 rue Alain Savary  21000 Dijon
#
#                                             mail  \
# 0           residence.vauban@crous-versailles.fr
# 1          residence.lacroix@crous-versailles.fr
# 2          residence.bagneux@crous-versailles.fr
# 3              residence.ile@crous-versailles.fr
# 4        residence.pacaterie@crous-versailles.fr
# ..                                           ...
# 783                herouville@crous-normandie.fr
# 784  pole-hebergement-besancon@crous-besancon.fr
# 785            pole-hebergement-nfc@crous-bfc.fr
# 786                                          NaN
# 787                                          NaN
#
#                                phone  ...  Mean Loyer  \
# 0                     01 80 73 04 00  ...  435.000000
# 1                     01 30 30 38 53  ...  334.000000
# 2                     01 86 63 00 90  ...  345.500000
# 3                     01 69 07 68 96  ...  362.000000
# 4                     01 69 15 75 98  ...  154.000000
# ..                               ...  ...         ...
# 783                   02 31 47 61 23  ...  416.648333
# 784                   03 81 48 47 50  ...  457.333333
# 785  03.84.21.95.37 - 06.48.41.76.36  ...  403.571429
# 786                   03.45.34.84.57  ...         NaN
# 787                   03.45.34.84.81  ...         NaN
#
#                                  Surface Max Surface Min Surface Mean Surface  \
# 0                                     []         NaN         NaN          NaN
# 1                                     []         NaN         NaN          NaN
# 2                                 [28.0]        28.0        28.0    28.000000
# 3                                 [18.0]        18.0        18.0    18.000000
# 4                                     []         NaN         NaN          NaN
# ..                                   ...         ...         ...          ...
# 783  [9.0, 18.0, 30.0, 49.0, 65.0, 69.0]        69.0         9.0    40.000000
# 784                         [19.0, 35.3]        35.3        19.0    27.150000
# 785                   [18.0, 36.0, 51.5]        51.5        18.0    35.166667
# 786                                 None         NaN         NaN          NaN
# 787                                   []         NaN         NaN          NaN
#
#     Longitude   Latitude                   geometry                  LIBGEO  \
# 0    2.044151  48.779652   POINT (2.04415 48.77965)              Guyancourt
# 1    2.026887  49.048298   POINT (2.02689 49.04830)                   Cergy
# 2    2.316971  48.790691   POINT (2.31697 48.79069)                 Bagneux
# 3    2.157896  48.698803   POINT (2.15790 48.69880)        Bures-sur-Yvette
# 4    2.184678  48.701542   POINT (2.18468 48.70154)                   Orsay
# ..        ...        ...                        ...                     ...
# 783 -0.339214  49.203205  POINT (-0.33921 49.20321)  Hérouville-Saint-Clair
# 784  6.015343  47.236507   POINT (6.01534 47.23651)                Besançon
# 785  6.853714  47.638988   POINT (6.85371 47.63899)                 Belfort
# 786  5.035332  47.322498   POINT (5.03533 47.32250)                   Dijon
# 787  5.072239  47.310177   POINT (5.07224 47.31018)                   Dijon
#
#         upr.IPm2
# 0    21,73842264
# 1    20,65371054
# 2    24,98281618
# 3     21,2713506
# 4    21,07028697
# ..           ...
# 783  13,70540711
# 784  13,92609502
# 785  13,04684054
# 786  14,38634283
# 787  14,38634283
#
# [788 rows x 32 columns]

# %% [markdown]
# ## 1.4 Ajout des départements

# %%
gdf_dep = gpd.read_file("https://www.data.gouv.fr/fr/datasets/r/eb36371a-761d-44a8-93ec-3d728bec17ce")
gdf_dep.rename(columns = {'nom':'departement'}, inplace = True)
gdf_dep = gdf_dep[["departement", "geometry"]]
gdf_dep
# Out:
#           departement                                           geometry
# 0          La Réunion  MULTIPOLYGON (((55.21643 -21.03904, 55.21652 -...
# 1                Aude  POLYGON ((1.68872 43.27368, 1.69001 43.27423, ...
# 2         Haute-Loire  POLYGON ((3.08206 45.28988, 3.08209 45.29031, ...
# 3    Bouches-du-Rhône  MULTIPOLYGON (((4.23014 43.46047, 4.23025 43.4...
# 4      Lot-et-Garonne  POLYGON ((-0.14058 44.22648, -0.12931 44.23218...
# ..                ...                                                ...
# 97           Morbihan  MULTIPOLYGON (((-3.73508 48.11140, -3.73507 48...
# 98              Doubs  POLYGON ((5.69876 47.26464, 5.69877 47.26481, ...
# 99               Jura  MULTIPOLYGON (((5.25202 46.94451, 5.25208 46.9...
# 100           Ardèche  POLYGON ((3.86110 44.71118, 3.86110 44.71151, ...
# 101              Gard  POLYGON ((3.26190 44.09335, 3.26221 44.09389, ...
#
# [102 rows x 2 columns]

# %%
df = gpd.sjoin(df, gdf_dep, how='left', op='within')
# Out:
# /opt/mamba/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3373: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /tmp/ipykernel_14186/3352756710.py:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   df = gpd.sjoin(df, gdf_dep, how='left', op='within')

# %%
df
# Out:
#       id                                              title  \
# 0    205                                   Résidence Vauban
# 1    207                 Résidence Le Square de l'Echiquier
# 2    214                       Résidence Les Bas Longchamps
# 3    225                                 Résidence de l’Ile
# 4    228                             Résidence La Pacaterie
# ..   ...                                                ...
# 783  349  Cité Grémillon (secteur d'Hérouville-Saint-Clair)
# 784  331                           Résidence Antide Janvier
# 785  335                         Résidence Jean Paul Sartre
# 786  416                                              Maret
# 787  420                                          Antipodes
#
#                                         short_desc                     zone  \
# 0                                       Guyancourt                 YVELINES
# 1                                   Cergy-Pontoise               VAL D'OISE
# 2                                          Bagneux           HAUTS DE SEINE
# 3                                 Bures-sur-Yvette                  ESSONNE
# 4                                            Orsay                  ESSONNE
# ..                                             ...                      ...
# 783                                            NaN   Herouville Saint Clair
# 784                    Centre ville, sur les quais  Besançon - Centre ville
# 785                                   Centre ville                  Belfort
# 786  Logements proposés : chambres traditionnelles             DIJON CENTRE
# 787   Logements proposés: appartements du T1 au T3             DIJON CAMPUS
#
#                                                  infos  \
# 0    Description La résidence est située au cœur de...
# 1    DescriptionRésidence universitaire nouvellemen...
# 2    Description Résidence universitaire située à p...
# 3    Description Résidence universitaire située à p...
# 4    Description Résidence universitaire longée par...
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784  Localisation :\r\n Au centre ville, à proximit...
# 785  Localisation :\r\n La résidence Sartre est sit...
# 786                                                NaN
# 787  La résidence compte 350 logements (du T1 au T3...
#
#                                               services  \
# 0    Laverie \r\n  Salles de travail \r\n  Salles d...
# 1    Wifi \r\n   Laverie \r\n  salle de sport \r\n ...
# 2    Laverie \r\n    Salles de travail et de détent...
# 3    Salles de détente, une avec télévision \r\n   ...
# 4    Salles de détente             (télévision, ate...
# ..                                                 ...
# 783                        Gratuits (Sauf € = Payants)
# 784        Wifi Inclus dans le loyerPoint restoParking
# 785                    LaverieParking fermé (15€/mois)
# 786  La Résidence universitaire Maret, située en pl...
# 787  La résidence bénéficie de cabines téléphonique...
#
#                                                contact  \
# 0    Résidence Vauban\r\n 1 boulevard d’Alembert782...
# 1    Résidence Le Square de l'échiquier\n9 square d...
# 2    Résidence de Bagneux /Les Bas de Longchamps\r\...
# 3    Résidence de l’Ile\n14 rue du Docteur Collé - ...
# 4    Résidence La Pacaterie\nBâtiment 499 - rue de ...
# ..                                                 ...
# 783  Cité Grémillon (Secteur d'Hérouville-Saint-Cla...
# 784  Résidence Antide Janvier \r\n 49 T1 et de 27 T...
# 785  Résidence Jean-Paul Sartre \r\n 130 T1, 11 T1 ...
# 786  Résidence MARET \r\n 3 rue du Docteur Maret \r...
# 787  Résidence ANTIPODES \r\n 24/32 rue Alain Savar...
#
#                                                address  \
# 0              1 boulevard d’Alembert 78280 Guyancourt
# 1         9 square de l'échiquier 95800 Cergy-Pontoise
# 2                  2 rue Abraham Lincoln 92220 Bagneux
# 3    14 rue du Docteur Collé - bâtiment 227 du camp...
# 4       Bâtiment 499 - rue de la Pacaterie 91400 Orsay
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784                6 rue Antide Janvier 25000 Besançon
# 785                   Rue Gaston Deferre 90000 Belfort
# 786                3 rue du Docteur Maret  21000 Dijon
# 787                24/32 rue Alain Savary  21000 Dijon
#
#                                             mail  \
# 0           residence.vauban@crous-versailles.fr
# 1          residence.lacroix@crous-versailles.fr
# 2          residence.bagneux@crous-versailles.fr
# 3              residence.ile@crous-versailles.fr
# 4        residence.pacaterie@crous-versailles.fr
# ..                                           ...
# 783                herouville@crous-normandie.fr
# 784  pole-hebergement-besancon@crous-besancon.fr
# 785            pole-hebergement-nfc@crous-bfc.fr
# 786                                          NaN
# 787                                          NaN
#
#                                phone  ... Max Surface Min Surface  \
# 0                     01 80 73 04 00  ...         NaN         NaN
# 1                     01 30 30 38 53  ...         NaN         NaN
# 2                     01 86 63 00 90  ...        28.0        28.0
# 3                     01 69 07 68 96  ...        18.0        18.0
# 4                     01 69 15 75 98  ...         NaN         NaN
# ..                               ...  ...         ...         ...
# 783                   02 31 47 61 23  ...        69.0         9.0
# 784                   03 81 48 47 50  ...        35.3        19.0
# 785  03.84.21.95.37 - 06.48.41.76.36  ...        51.5        18.0
# 786                   03.45.34.84.57  ...         NaN         NaN
# 787                   03.45.34.84.81  ...         NaN         NaN
#
#     Mean Surface Longitude   Latitude                   geometry  \
# 0            NaN  2.044151  48.779652   POINT (2.04415 48.77965)
# 1            NaN  2.026887  49.048298   POINT (2.02689 49.04830)
# 2      28.000000  2.316971  48.790691   POINT (2.31697 48.79069)
# 3      18.000000  2.157896  48.698803   POINT (2.15790 48.69880)
# 4            NaN  2.184678  48.701542   POINT (2.18468 48.70154)
# ..           ...       ...        ...                        ...
# 783    40.000000 -0.339214  49.203205  POINT (-0.33921 49.20321)
# 784    27.150000  6.015343  47.236507   POINT (6.01534 47.23651)
# 785    35.166667  6.853714  47.638988   POINT (6.85371 47.63899)
# 786          NaN  5.035332  47.322498   POINT (5.03533 47.32250)
# 787          NaN  5.072239  47.310177   POINT (5.07224 47.31018)
#
#                      LIBGEO     upr.IPm2 index_right            departement
# 0                Guyancourt  21,73842264          73               Yvelines
# 1                     Cergy  20,65371054          67             Val-d'Oise
# 2                   Bagneux  24,98281618          35         Hauts-de-Seine
# 3          Bures-sur-Yvette   21,2713506           8                Essonne
# 4                     Orsay  21,07028697           8                Essonne
# ..                      ...          ...         ...                    ...
# 783  Hérouville-Saint-Clair  13,70540711          69               Calvados
# 784                Besançon  13,92609502          98                  Doubs
# 785                 Belfort  13,04684054          86  Territoire-de-Belfort
# 786                   Dijon  14,38634283          78              Côte-d'Or
# 787                   Dijon  14,38634283          78              Côte-d'Or
#
# [788 rows x 34 columns]

# %%
del df['index_right'] #on supprime l'index right pour la prochaine jointure
df
# Out:
#       id                                              title  \
# 0    205                                   Résidence Vauban
# 1    207                 Résidence Le Square de l'Echiquier
# 2    214                       Résidence Les Bas Longchamps
# 3    225                                 Résidence de l’Ile
# 4    228                             Résidence La Pacaterie
# ..   ...                                                ...
# 783  349  Cité Grémillon (secteur d'Hérouville-Saint-Clair)
# 784  331                           Résidence Antide Janvier
# 785  335                         Résidence Jean Paul Sartre
# 786  416                                              Maret
# 787  420                                          Antipodes
#
#                                         short_desc                     zone  \
# 0                                       Guyancourt                 YVELINES
# 1                                   Cergy-Pontoise               VAL D'OISE
# 2                                          Bagneux           HAUTS DE SEINE
# 3                                 Bures-sur-Yvette                  ESSONNE
# 4                                            Orsay                  ESSONNE
# ..                                             ...                      ...
# 783                                            NaN   Herouville Saint Clair
# 784                    Centre ville, sur les quais  Besançon - Centre ville
# 785                                   Centre ville                  Belfort
# 786  Logements proposés : chambres traditionnelles             DIJON CENTRE
# 787   Logements proposés: appartements du T1 au T3             DIJON CAMPUS
#
#                                                  infos  \
# 0    Description La résidence est située au cœur de...
# 1    DescriptionRésidence universitaire nouvellemen...
# 2    Description Résidence universitaire située à p...
# 3    Description Résidence universitaire située à p...
# 4    Description Résidence universitaire longée par...
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784  Localisation :\r\n Au centre ville, à proximit...
# 785  Localisation :\r\n La résidence Sartre est sit...
# 786                                                NaN
# 787  La résidence compte 350 logements (du T1 au T3...
#
#                                               services  \
# 0    Laverie \r\n  Salles de travail \r\n  Salles d...
# 1    Wifi \r\n   Laverie \r\n  salle de sport \r\n ...
# 2    Laverie \r\n    Salles de travail et de détent...
# 3    Salles de détente, une avec télévision \r\n   ...
# 4    Salles de détente             (télévision, ate...
# ..                                                 ...
# 783                        Gratuits (Sauf € = Payants)
# 784        Wifi Inclus dans le loyerPoint restoParking
# 785                    LaverieParking fermé (15€/mois)
# 786  La Résidence universitaire Maret, située en pl...
# 787  La résidence bénéficie de cabines téléphonique...
#
#                                                contact  \
# 0    Résidence Vauban\r\n 1 boulevard d’Alembert782...
# 1    Résidence Le Square de l'échiquier\n9 square d...
# 2    Résidence de Bagneux /Les Bas de Longchamps\r\...
# 3    Résidence de l’Ile\n14 rue du Docteur Collé - ...
# 4    Résidence La Pacaterie\nBâtiment 499 - rue de ...
# ..                                                 ...
# 783  Cité Grémillon (Secteur d'Hérouville-Saint-Cla...
# 784  Résidence Antide Janvier \r\n 49 T1 et de 27 T...
# 785  Résidence Jean-Paul Sartre \r\n 130 T1, 11 T1 ...
# 786  Résidence MARET \r\n 3 rue du Docteur Maret \r...
# 787  Résidence ANTIPODES \r\n 24/32 rue Alain Savar...
#
#                                                address  \
# 0              1 boulevard d’Alembert 78280 Guyancourt
# 1         9 square de l'échiquier 95800 Cergy-Pontoise
# 2                  2 rue Abraham Lincoln 92220 Bagneux
# 3    14 rue du Docteur Collé - bâtiment 227 du camp...
# 4       Bâtiment 499 - rue de la Pacaterie 91400 Orsay
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784                6 rue Antide Janvier 25000 Besançon
# 785                   Rue Gaston Deferre 90000 Belfort
# 786                3 rue du Docteur Maret  21000 Dijon
# 787                24/32 rue Alain Savary  21000 Dijon
#
#                                             mail  \
# 0           residence.vauban@crous-versailles.fr
# 1          residence.lacroix@crous-versailles.fr
# 2          residence.bagneux@crous-versailles.fr
# 3              residence.ile@crous-versailles.fr
# 4        residence.pacaterie@crous-versailles.fr
# ..                                           ...
# 783                herouville@crous-normandie.fr
# 784  pole-hebergement-besancon@crous-besancon.fr
# 785            pole-hebergement-nfc@crous-bfc.fr
# 786                                          NaN
# 787                                          NaN
#
#                                phone  ...  \
# 0                     01 80 73 04 00  ...
# 1                     01 30 30 38 53  ...
# 2                     01 86 63 00 90  ...
# 3                     01 69 07 68 96  ...
# 4                     01 69 15 75 98  ...
# ..                               ...  ...
# 783                   02 31 47 61 23  ...
# 784                   03 81 48 47 50  ...
# 785  03.84.21.95.37 - 06.48.41.76.36  ...
# 786                   03.45.34.84.57  ...
# 787                   03.45.34.84.81  ...
#
#                                  Surface Max Surface Min Surface Mean Surface  \
# 0                                     []         NaN         NaN          NaN
# 1                                     []         NaN         NaN          NaN
# 2                                 [28.0]        28.0        28.0    28.000000
# 3                                 [18.0]        18.0        18.0    18.000000
# 4                                     []         NaN         NaN          NaN
# ..                                   ...         ...         ...          ...
# 783  [9.0, 18.0, 30.0, 49.0, 65.0, 69.0]        69.0         9.0    40.000000
# 784                         [19.0, 35.3]        35.3        19.0    27.150000
# 785                   [18.0, 36.0, 51.5]        51.5        18.0    35.166667
# 786                                 None         NaN         NaN          NaN
# 787                                   []         NaN         NaN          NaN
#
#     Longitude   Latitude                   geometry                  LIBGEO  \
# 0    2.044151  48.779652   POINT (2.04415 48.77965)              Guyancourt
# 1    2.026887  49.048298   POINT (2.02689 49.04830)                   Cergy
# 2    2.316971  48.790691   POINT (2.31697 48.79069)                 Bagneux
# 3    2.157896  48.698803   POINT (2.15790 48.69880)        Bures-sur-Yvette
# 4    2.184678  48.701542   POINT (2.18468 48.70154)                   Orsay
# ..        ...        ...                        ...                     ...
# 783 -0.339214  49.203205  POINT (-0.33921 49.20321)  Hérouville-Saint-Clair
# 784  6.015343  47.236507   POINT (6.01534 47.23651)                Besançon
# 785  6.853714  47.638988   POINT (6.85371 47.63899)                 Belfort
# 786  5.035332  47.322498   POINT (5.03533 47.32250)                   Dijon
# 787  5.072239  47.310177   POINT (5.07224 47.31018)                   Dijon
#
#         upr.IPm2            departement
# 0    21,73842264               Yvelines
# 1    20,65371054             Val-d'Oise
# 2    24,98281618         Hauts-de-Seine
# 3     21,2713506                Essonne
# 4    21,07028697                Essonne
# ..           ...                    ...
# 783  13,70540711               Calvados
# 784  13,92609502                  Doubs
# 785  13,04684054  Territoire-de-Belfort
# 786  14,38634283              Côte-d'Or
# 787  14,38634283              Côte-d'Or
#
# [788 rows x 33 columns]

# %% [markdown]
# ## 1.5. Association de résidences à une école

# %%
df_schools = pd.read_csv("https://www.data.gouv.fr/fr/datasets/r/8f040d23-a09f-4dee-aa19-0892602490d8", sep = ';')
df_schools
# Out:
#     etablissement_id_paysage  \
# 0                      jKV15
# 1                      76MfM
# 2                      4i3C4
# 3                      Hq9dm
# 4                      WjVHD
# ..                       ...
# 245                    n2vXC
# 246                    atbEK
# 247                    06SE7
# 248                    t6Cq5
# 249                    LsQ24
#
#                                                 uo_lib           nom_court  \
# 0                        École centrale d'électronique                 ECE
# 1                         École d'ingénieurs de Purpan           EI Purpan
# 2    École nationale supérieure d'architecture de P...             ENSAPLV
# 3    École nationale supérieure de création industr...  Ensci-Les Ateliers
# 4    École nationale supérieure d'informatique pour...                 NaN
# ..                                                 ...                 ...
# 245       Institut supérieur d’agriculture Rhône-Alpes          Isara-Lyon
# 246                             La Rochelle Université                 NaN
# 247                 Université de Bretagne Occidentale                 NaN
# 248                             Université de Lorraine                 NaN
# 249                      Université Le Havre Normandie                 NaN
#
#       sigle type_d_etablissement      typologie_d_universites_et_assimiles  \
# 0       NaN                École                                       NaN
# 1       EIP                École                                       NaN
# 2       NaN                École                                       NaN
# 3       NaN                École                                       NaN
# 4    ENSIIE                École                                       NaN
# ..      ...                  ...                                       ...
# 245     NaN                École                                       NaN
# 246     NaN           Université  Université pluridisciplinaire hors santé
# 247     UBO           Université  Université pluridisciplinaire avec santé
# 248     NaN  Grand établissement                                       NaN
# 249     NaN           Université  Université pluridisciplinaire hors santé
#
#     secteur_d_etablissement vague_contractuelle  \
# 0                     Privé             Vague D
# 1                     Privé             Vague A
# 2                    Public                 NaN
# 3                    Public                 NaN
# 4                    Public             Vague E
# ..                      ...                 ...
# 245                   Privé             Vague A
# 246                  Public             Vague B
# 247                  Public             Vague B
# 248                  Public             Vague C
# 249                  Public             Vague B
#
#                                           localisation  \
# 0                  Île-de-France>Paris>Paris>Paris 15e
# 1            Occitanie>Toulouse>Haute-Garonne>Toulouse
# 2                  Île-de-France>Paris>Paris>Paris 19e
# 3                  Île-de-France>Paris>Paris>Paris  8e
# 4    Île-de-France>Versailles>Essonne>Évry-Courcour...
# ..                                                 ...
# 245            Auvergne-Rhône-Alpes>Lyon>Rhône>Lyon 7e
# 246  Nouvelle-Aquitaine>Poitiers>Charente-Maritime>...
# 247                    Bretagne>Rennes>Finistère>Brest
# 248      Grand Est>Nancy-Metz>Meurthe-et-Moselle>Nancy
# 249            Normandie>Rouen>Seine-Maritime>Le Havre
#
#                                                    url  ...  \
# 0                  https://www.ece.fr/ecole-ingenieur/  ...
# 1                                http://www.purpan.fr/  ...
# 2                http://www.paris-lavillette.archi.fr/  ...
# 3    https://www.ensci.com/2017-2018-ensci-les-atel...  ...
# 4                               https://www.ensiie.fr/  ...
# ..                                                 ...  ...
# 245                              https://www.isara.fr/  ...
# 246                    https://www.univ-larochelle.fr/  ...
# 247                          http://www.univ-brest.fr/  ...
# 248                       http://www.univ-lorraine.fr/  ...
# 249                       https://www.univ-lehavre.fr/  ...
#
#     identifiant_programmes_lolf statut_operateur_lolf  libelle_missions_lolf  \
# 0                           NaN                   NaN                    NaN
# 1                           NaN                   NaN                    NaN
# 2                           NaN                   NaN                    NaN
# 3                           NaN                   NaN                    NaN
# 4                           NaN                   NaN                    NaN
# ..                          ...                   ...                    ...
# 245                         NaN                   NaN                    NaN
# 246                         NaN                   NaN                    NaN
# 247                         NaN                   NaN                    NaN
# 248                         NaN                   NaN                    NaN
# 249                         NaN                   NaN                    NaN
#
#      libelle_programmes_lolf libelle_programme_lolf_chef_de_file  \
# 0                        NaN                                 NaN
# 1                        NaN                                 NaN
# 2                        NaN                                 NaN
# 3                        NaN                                 NaN
# 4                        NaN                                 NaN
# ..                       ...                                 ...
# 245                      NaN                                 NaN
# 246                      NaN                                 NaN
# 247                      NaN                                 NaN
# 248                      NaN                                 NaN
# 249                      NaN                                 NaN
#
#     identifiants_autres_programmes_lolf libelles_autres_programmes_lolf  \
# 0                                   NaN                             NaN
# 1                                   NaN                             NaN
# 2                                   NaN                             NaN
# 3                                   NaN                             NaN
# 4                                   NaN                             NaN
# ..                                  ...                             ...
# 245                                 NaN                             NaN
# 246                                 NaN                             NaN
# 247                                 NaN                             NaN
# 248                                 NaN                             NaN
# 249                                 NaN                             NaN
#
#     identifiant_programme_lolf_chef_de_file libelle_mission_chef_de_file  \
# 0                                       NaN                          NaN
# 1                                       NaN                          NaN
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4                                       NaN                          NaN
# ..                                      ...                          ...
# 245                                     NaN                          NaN
# 246                                     NaN                          NaN
# 247                                     NaN                          NaN
# 248                                     NaN                          NaN
# 249                                     NaN                          NaN
#
#     compte_googleplus
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 245               NaN
# 246               NaN
# 247               NaN
# 248               NaN
# 249               NaN
#
# [250 rows x 120 columns]

# %%
df_schools = df_schools.dropna(subset=['coordonnees'])
df_schools = df_schools.reset_index()

# %%
df_schools[["uo_lib","type_d_etablissement","coordonnees","inscrits_2017"]]
# Out:
#                                                 uo_lib type_d_etablissement  \
# 0                        École centrale d'électronique                École
# 1                         École d'ingénieurs de Purpan                École
# 2    École nationale supérieure d'architecture de P...                École
# 3    École nationale supérieure de création industr...                École
# 4    École nationale supérieure d'informatique pour...                École
# ..                                                 ...                  ...
# 244       Institut supérieur d’agriculture Rhône-Alpes                École
# 245                             La Rochelle Université           Université
# 246                 Université de Bretagne Occidentale           Université
# 247                             Université de Lorraine  Grand établissement
# 248                      Université Le Havre Normandie           Université
#
#             coordonnees inscrits_2017
# 0      48.85152,2.28683           NaN
# 1    43.601838,1.400296           986
# 2      48.89325,2.38192           NaN
# 3       48.8584,2.36934           NaN
# 4       48.6262,2.43202           565
# ..                  ...           ...
# 244  45.727895,4.836377           937
# 245   46.14774,-1.15504         8 373
# 246    48.39803,-4.5077        19 986
# 247     48.6962,6.17634        58 925
# 248    49.49647,0.12896         7 880
#
# [249 rows x 4 columns]

# %%
Longitude = []
Latitude = []
for element in df_schools['coordonnees']:
    geocalisation = element
    geocalisation = geocalisation.replace(',', ' ')
    word =  nltk.word_tokenize(geocalisation, language='french')
    Latitude.append(float(word[0]))
    Longitude.append(float(word[1]))
df_schools['Longitude'] = Longitude
df_schools['Latitude'] = Latitude
df_schools = gpd.GeoDataFrame(df_schools, geometry=gpd.points_from_xy(df_schools.Longitude, df_schools.Latitude))

# %%
df_schools =  df_schools[['uo_lib', 'inscrits_2015', 'geometry']]
df_schools
# Out:
#                                                 uo_lib inscrits_2015  \
# 0                        École centrale d'électronique           NaN
# 1                         École d'ingénieurs de Purpan           946
# 2    École nationale supérieure d'architecture de P...           NaN
# 3    École nationale supérieure de création industr...           NaN
# 4    École nationale supérieure d'informatique pour...           596
# ..                                                 ...           ...
# 244       Institut supérieur d’agriculture Rhône-Alpes           866
# 245                             La Rochelle Université         7 875
# 246                 Université de Bretagne Occidentale        19 103
# 247                             Université de Lorraine        56 209
# 248                      Université Le Havre Normandie         7 479
#
#                       geometry
# 0     POINT (2.28683 48.85152)
# 1     POINT (1.40030 43.60184)
# 2     POINT (2.38192 48.89325)
# 3     POINT (2.36934 48.85840)
# 4     POINT (2.43202 48.62620)
# ..                         ...
# 244   POINT (4.83638 45.72789)
# 245  POINT (-1.15504 46.14774)
# 246  POINT (-4.50770 48.39803)
# 247   POINT (6.17634 48.69620)
# 248   POINT (0.12896 49.49647)
#
# [249 rows x 3 columns]

# %%
df.crs = "epsg:4326"
df_schools.crs = "epsg:4326"

# %%
df1 = df
df1 = df1.to_crs(3043) #On prend une projection en mètres
df1['geometry'] = df1['geometry'].buffer(5000) #On prend un rayon de 5km 
df1 = df1.to_crs(4326) #on repasse dans la projection uselle 
df1
# Out:
#       id                                              title  \
# 0    205                                   Résidence Vauban
# 1    207                 Résidence Le Square de l'Echiquier
# 2    214                       Résidence Les Bas Longchamps
# 3    225                                 Résidence de l’Ile
# 4    228                             Résidence La Pacaterie
# ..   ...                                                ...
# 783  349  Cité Grémillon (secteur d'Hérouville-Saint-Clair)
# 784  331                           Résidence Antide Janvier
# 785  335                         Résidence Jean Paul Sartre
# 786  416                                              Maret
# 787  420                                          Antipodes
#
#                                         short_desc                     zone  \
# 0                                       Guyancourt                 YVELINES
# 1                                   Cergy-Pontoise               VAL D'OISE
# 2                                          Bagneux           HAUTS DE SEINE
# 3                                 Bures-sur-Yvette                  ESSONNE
# 4                                            Orsay                  ESSONNE
# ..                                             ...                      ...
# 783                                            NaN   Herouville Saint Clair
# 784                    Centre ville, sur les quais  Besançon - Centre ville
# 785                                   Centre ville                  Belfort
# 786  Logements proposés : chambres traditionnelles             DIJON CENTRE
# 787   Logements proposés: appartements du T1 au T3             DIJON CAMPUS
#
#                                                  infos  \
# 0    Description La résidence est située au cœur de...
# 1    DescriptionRésidence universitaire nouvellemen...
# 2    Description Résidence universitaire située à p...
# 3    Description Résidence universitaire située à p...
# 4    Description Résidence universitaire longée par...
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784  Localisation :\r\n Au centre ville, à proximit...
# 785  Localisation :\r\n La résidence Sartre est sit...
# 786                                                NaN
# 787  La résidence compte 350 logements (du T1 au T3...
#
#                                               services  \
# 0    Laverie \r\n  Salles de travail \r\n  Salles d...
# 1    Wifi \r\n   Laverie \r\n  salle de sport \r\n ...
# 2    Laverie \r\n    Salles de travail et de détent...
# 3    Salles de détente, une avec télévision \r\n   ...
# 4    Salles de détente             (télévision, ate...
# ..                                                 ...
# 783                        Gratuits (Sauf € = Payants)
# 784        Wifi Inclus dans le loyerPoint restoParking
# 785                    LaverieParking fermé (15€/mois)
# 786  La Résidence universitaire Maret, située en pl...
# 787  La résidence bénéficie de cabines téléphonique...
#
#                                                contact  \
# 0    Résidence Vauban\r\n 1 boulevard d’Alembert782...
# 1    Résidence Le Square de l'échiquier\n9 square d...
# 2    Résidence de Bagneux /Les Bas de Longchamps\r\...
# 3    Résidence de l’Ile\n14 rue du Docteur Collé - ...
# 4    Résidence La Pacaterie\nBâtiment 499 - rue de ...
# ..                                                 ...
# 783  Cité Grémillon (Secteur d'Hérouville-Saint-Cla...
# 784  Résidence Antide Janvier \r\n 49 T1 et de 27 T...
# 785  Résidence Jean-Paul Sartre \r\n 130 T1, 11 T1 ...
# 786  Résidence MARET \r\n 3 rue du Docteur Maret \r...
# 787  Résidence ANTIPODES \r\n 24/32 rue Alain Savar...
#
#                                                address  \
# 0              1 boulevard d’Alembert 78280 Guyancourt
# 1         9 square de l'échiquier 95800 Cergy-Pontoise
# 2                  2 rue Abraham Lincoln 92220 Bagneux
# 3    14 rue du Docteur Collé - bâtiment 227 du camp...
# 4       Bâtiment 499 - rue de la Pacaterie 91400 Orsay
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784                6 rue Antide Janvier 25000 Besançon
# 785                   Rue Gaston Deferre 90000 Belfort
# 786                3 rue du Docteur Maret  21000 Dijon
# 787                24/32 rue Alain Savary  21000 Dijon
#
#                                             mail  \
# 0           residence.vauban@crous-versailles.fr
# 1          residence.lacroix@crous-versailles.fr
# 2          residence.bagneux@crous-versailles.fr
# 3              residence.ile@crous-versailles.fr
# 4        residence.pacaterie@crous-versailles.fr
# ..                                           ...
# 783                herouville@crous-normandie.fr
# 784  pole-hebergement-besancon@crous-besancon.fr
# 785            pole-hebergement-nfc@crous-bfc.fr
# 786                                          NaN
# 787                                          NaN
#
#                                phone  ...  \
# 0                     01 80 73 04 00  ...
# 1                     01 30 30 38 53  ...
# 2                     01 86 63 00 90  ...
# 3                     01 69 07 68 96  ...
# 4                     01 69 15 75 98  ...
# ..                               ...  ...
# 783                   02 31 47 61 23  ...
# 784                   03 81 48 47 50  ...
# 785  03.84.21.95.37 - 06.48.41.76.36  ...
# 786                   03.45.34.84.57  ...
# 787                   03.45.34.84.81  ...
#
#                                  Surface Max Surface Min Surface Mean Surface  \
# 0                                     []         NaN         NaN          NaN
# 1                                     []         NaN         NaN          NaN
# 2                                 [28.0]        28.0        28.0    28.000000
# 3                                 [18.0]        18.0        18.0    18.000000
# 4                                     []         NaN         NaN          NaN
# ..                                   ...         ...         ...          ...
# 783  [9.0, 18.0, 30.0, 49.0, 65.0, 69.0]        69.0         9.0    40.000000
# 784                         [19.0, 35.3]        35.3        19.0    27.150000
# 785                   [18.0, 36.0, 51.5]        51.5        18.0    35.166667
# 786                                 None         NaN         NaN          NaN
# 787                                   []         NaN         NaN          NaN
#
#     Longitude   Latitude                                           geometry  \
# 0    2.044151  48.779652  POLYGON ((2.11220 48.78020, 2.11195 48.77579, ...
# 1    2.026887  49.048298  POLYGON ((2.09530 49.04885, 2.09505 49.04444, ...
# 2    2.316971  48.790691  POLYGON ((2.38504 48.79107, 2.38477 48.78666, ...
# 3    2.157896  48.698803  POLYGON ((2.22584 48.69928, 2.22558 48.69487, ...
# 4    2.184678  48.701542  POLYGON ((2.25263 48.70200, 2.25236 48.69759, ...
# ..        ...        ...                                                ...
# 783 -0.339214  49.203205  POLYGON ((-0.27069 49.20517, -0.27073 49.20076...
# 784  6.015343  47.236507  POLYGON ((6.08131 47.23475, 6.08073 47.23036, ...
# 785  6.853714  47.638988  POLYGON ((6.92012 47.63674, 6.91948 47.63235, ...
# 786  5.035332  47.322498  POLYGON ((5.10145 47.32130, 5.10096 47.31690, ...
# 787  5.072239  47.310177  POLYGON ((5.13834 47.30896, 5.13785 47.30456, ...
#
#                      LIBGEO     upr.IPm2            departement
# 0                Guyancourt  21,73842264               Yvelines
# 1                     Cergy  20,65371054             Val-d'Oise
# 2                   Bagneux  24,98281618         Hauts-de-Seine
# 3          Bures-sur-Yvette   21,2713506                Essonne
# 4                     Orsay  21,07028697                Essonne
# ..                      ...          ...                    ...
# 783  Hérouville-Saint-Clair  13,70540711               Calvados
# 784                Besançon  13,92609502                  Doubs
# 785                 Belfort  13,04684054  Territoire-de-Belfort
# 786                   Dijon  14,38634283              Côte-d'Or
# 787                   Dijon  14,38634283              Côte-d'Or
#
# [788 rows x 33 columns]

# %%
df_schools.within(df1['geometry'][1])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 244    False
# 245    False
# 246    False
# 247    False
# 248    False
# Length: 249, dtype: bool

# %%
"""
essai sur la résidence de Cergy 
"""
a = df_schools.within(df1['geometry'][1])
i = 0 
for element in a : 
    if element == True: 
        print(df_schools['uo_lib'][i])
    i = i + 1
# Out:
# École nationale supérieure de l'électronique et de ses applications de Cergy
# Itescia
# École supérieure des sciences économiques et commerciales
# ECAM-EPMI
# École de biologie industrielle
# École nationale supérieure d'arts de Paris-Cergy
# CY Cergy Paris Université

# %%
Schools = [] #on crée une liste pour stocker la liste des écoles 
Nbstudents = [] #on crée une liste pour stocker la liste du nombre d'étudiants
for residence in df1['geometry']: #on prend pour chaque résidence le cercle de 5 km autour de cette résidence
    S = [] #stocke les écoles pour la résidence
    N = [] #idem pour le nb d'étudiants 
    i = 0 #index 
    a = df_schools.within(residence) #On utilise gpd.within qui regarde pour chaque élèment si sa coordonnée est dans le polygone résidence
    for element in a : #on regarde pour chaque élèment de a si l'école est dans le cercle de 5km autour de la résidence
        if element == True: 
            S.append(df_schools['uo_lib'][i]) #on ajoute l'école de l'index i 
            N.append(df_schools['inscrits_2015'][i]) #idem pour le nombre d'étudiants
        i = i + 1
    Schools.append(S) 
    Nbstudents.append(N)
df1['Schools'] = Schools
df1['Nbstudents'] = Nbstudents
df1
# Out:
#       id                                              title  \
# 0    205                                   Résidence Vauban
# 1    207                 Résidence Le Square de l'Echiquier
# 2    214                       Résidence Les Bas Longchamps
# 3    225                                 Résidence de l’Ile
# 4    228                             Résidence La Pacaterie
# ..   ...                                                ...
# 783  349  Cité Grémillon (secteur d'Hérouville-Saint-Clair)
# 784  331                           Résidence Antide Janvier
# 785  335                         Résidence Jean Paul Sartre
# 786  416                                              Maret
# 787  420                                          Antipodes
#
#                                         short_desc                     zone  \
# 0                                       Guyancourt                 YVELINES
# 1                                   Cergy-Pontoise               VAL D'OISE
# 2                                          Bagneux           HAUTS DE SEINE
# 3                                 Bures-sur-Yvette                  ESSONNE
# 4                                            Orsay                  ESSONNE
# ..                                             ...                      ...
# 783                                            NaN   Herouville Saint Clair
# 784                    Centre ville, sur les quais  Besançon - Centre ville
# 785                                   Centre ville                  Belfort
# 786  Logements proposés : chambres traditionnelles             DIJON CENTRE
# 787   Logements proposés: appartements du T1 au T3             DIJON CAMPUS
#
#                                                  infos  \
# 0    Description La résidence est située au cœur de...
# 1    DescriptionRésidence universitaire nouvellemen...
# 2    Description Résidence universitaire située à p...
# 3    Description Résidence universitaire située à p...
# 4    Description Résidence universitaire longée par...
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784  Localisation :\r\n Au centre ville, à proximit...
# 785  Localisation :\r\n La résidence Sartre est sit...
# 786                                                NaN
# 787  La résidence compte 350 logements (du T1 au T3...
#
#                                               services  \
# 0    Laverie \r\n  Salles de travail \r\n  Salles d...
# 1    Wifi \r\n   Laverie \r\n  salle de sport \r\n ...
# 2    Laverie \r\n    Salles de travail et de détent...
# 3    Salles de détente, une avec télévision \r\n   ...
# 4    Salles de détente             (télévision, ate...
# ..                                                 ...
# 783                        Gratuits (Sauf € = Payants)
# 784        Wifi Inclus dans le loyerPoint restoParking
# 785                    LaverieParking fermé (15€/mois)
# 786  La Résidence universitaire Maret, située en pl...
# 787  La résidence bénéficie de cabines téléphonique...
#
#                                                contact  \
# 0    Résidence Vauban\r\n 1 boulevard d’Alembert782...
# 1    Résidence Le Square de l'échiquier\n9 square d...
# 2    Résidence de Bagneux /Les Bas de Longchamps\r\...
# 3    Résidence de l’Ile\n14 rue du Docteur Collé - ...
# 4    Résidence La Pacaterie\nBâtiment 499 - rue de ...
# ..                                                 ...
# 783  Cité Grémillon (Secteur d'Hérouville-Saint-Cla...
# 784  Résidence Antide Janvier \r\n 49 T1 et de 27 T...
# 785  Résidence Jean-Paul Sartre \r\n 130 T1, 11 T1 ...
# 786  Résidence MARET \r\n 3 rue du Docteur Maret \r...
# 787  Résidence ANTIPODES \r\n 24/32 rue Alain Savar...
#
#                                                address  \
# 0              1 boulevard d’Alembert 78280 Guyancourt
# 1         9 square de l'échiquier 95800 Cergy-Pontoise
# 2                  2 rue Abraham Lincoln 92220 Bagneux
# 3    14 rue du Docteur Collé - bâtiment 227 du camp...
# 4       Bâtiment 499 - rue de la Pacaterie 91400 Orsay
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784                6 rue Antide Janvier 25000 Besançon
# 785                   Rue Gaston Deferre 90000 Belfort
# 786                3 rue du Docteur Maret  21000 Dijon
# 787                24/32 rue Alain Savary  21000 Dijon
#
#                                             mail  \
# 0           residence.vauban@crous-versailles.fr
# 1          residence.lacroix@crous-versailles.fr
# 2          residence.bagneux@crous-versailles.fr
# 3              residence.ile@crous-versailles.fr
# 4        residence.pacaterie@crous-versailles.fr
# ..                                           ...
# 783                herouville@crous-normandie.fr
# 784  pole-hebergement-besancon@crous-besancon.fr
# 785            pole-hebergement-nfc@crous-bfc.fr
# 786                                          NaN
# 787                                          NaN
#
#                                phone  ... Min Surface Mean Surface Longitude  \
# 0                     01 80 73 04 00  ...         NaN          NaN  2.044151
# 1                     01 30 30 38 53  ...         NaN          NaN  2.026887
# 2                     01 86 63 00 90  ...        28.0    28.000000  2.316971
# 3                     01 69 07 68 96  ...        18.0    18.000000  2.157896
# 4                     01 69 15 75 98  ...         NaN          NaN  2.184678
# ..                               ...  ...         ...          ...       ...
# 783                   02 31 47 61 23  ...         9.0    40.000000 -0.339214
# 784                   03 81 48 47 50  ...        19.0    27.150000  6.015343
# 785  03.84.21.95.37 - 06.48.41.76.36  ...        18.0    35.166667  6.853714
# 786                   03.45.34.84.57  ...         NaN          NaN  5.035332
# 787                   03.45.34.84.81  ...         NaN          NaN  5.072239
#
#       Latitude                                           geometry  \
# 0    48.779652  POLYGON ((2.11220 48.78020, 2.11195 48.77579, ...
# 1    49.048298  POLYGON ((2.09530 49.04885, 2.09505 49.04444, ...
# 2    48.790691  POLYGON ((2.38504 48.79107, 2.38477 48.78666, ...
# 3    48.698803  POLYGON ((2.22584 48.69928, 2.22558 48.69487, ...
# 4    48.701542  POLYGON ((2.25263 48.70200, 2.25236 48.69759, ...
# ..         ...                                                ...
# 783  49.203205  POLYGON ((-0.27069 49.20517, -0.27073 49.20076...
# 784  47.236507  POLYGON ((6.08131 47.23475, 6.08073 47.23036, ...
# 785  47.638988  POLYGON ((6.92012 47.63674, 6.91948 47.63235, ...
# 786  47.322498  POLYGON ((5.10145 47.32130, 5.10096 47.31690, ...
# 787  47.310177  POLYGON ((5.13834 47.30896, 5.13785 47.30456, ...
#
#                      LIBGEO     upr.IPm2            departement  \
# 0                Guyancourt  21,73842264               Yvelines
# 1                     Cergy  20,65371054             Val-d'Oise
# 2                   Bagneux  24,98281618         Hauts-de-Seine
# 3          Bures-sur-Yvette   21,2713506                Essonne
# 4                     Orsay  21,07028697                Essonne
# ..                      ...          ...                    ...
# 783  Hérouville-Saint-Clair  13,70540711               Calvados
# 784                Besançon  13,92609502                  Doubs
# 785                 Belfort  13,04684054  Territoire-de-Belfort
# 786                   Dijon  14,38634283              Côte-d'Or
# 787                   Dijon  14,38634283              Côte-d'Or
#
#                                                Schools  \
# 0    [École supérieure des techniques aéronautiques...
# 1    [École nationale supérieure de l'électronique ...
# 2    [École supérieure d'ingénieurs des travaux de ...
# 3    [Institut Mines-Télécom, au périmètre des écol...
# 4    [Institut Mines-Télécom, au périmètre des écol...
# ..                                                 ...
# 783  [École supérieure d'arts et médias de Caen - C...
# 784  [École nationale supérieure de mécanique et de...
# 785  [École supérieure des technologies et des affa...
# 786  [Université de Bourgogne, Burgundy School of B...
# 787  [Université de Bourgogne, Burgundy School of B...
#
#                                 Nbstudents
# 0                                  [1 803]
# 1    [861, nan, 4 868, 697, 716, nan, nan]
# 2       [321, 2 372, 1 875, nan, nan, nan]
# 3                     [nan, nan, nan, nan]
# 4                     [nan, nan, nan, nan]
# ..                                     ...
# 783                [nan, 716, 453, 27 148]
# 784                          [830, 20 314]
# 785                                  [nan]
# 786                        [26 471, 2 172]
# 787                        [26 471, 2 172]
#
# [788 rows x 35 columns]

# %% [markdown]
# # II. Visualisation

# %% [markdown]
# ## 2.1 Portrait économique et statistique des résidences

# %%
df['prix_par_m2_min'] = df['Min Loyer']/df['Min Surface'] # On crée une nouvelle variable prix_par_m2_min

# %%
df["upr.IPm2"] = df["upr.IPm2"].apply(lambda x : x.replace(',', '.')) #on remplace les , par des points pour ensuite transformet cette colonne en float

# %%
df["upr.IPm2"] = df["upr.IPm2"].astype(float)

# %%
df.groupby(['departement']).mean().sort_values('prix_par_m2_min')

# %% [markdown]
# ## Construction des graphiques

# %%
df2 = df.groupby(['departement']).mean().sort_values('prix_par_m2_min')
df2 = df2.loc[(df2['prix_par_m2_min']>1)]

# %%
df2['departement'] = df2.index #je crée une colonne qui correspond à l'index (la colonne regions)

# %%
sns.barplot(y='departement', x='prix_par_m2_min', data=df2, width= 0.2, orient="h")

# %% [markdown]
# ## Ajout de la colonne 'prix_par_m2_max'(qui correspond le plus souvent à des logements en colocation (T2/T3/T4))

# %%
df['prix_par_m2_max'] = df['Max Loyer']/df['Max Surface'] # On crée une nouvelle variable prix_par_m2_min

# %%
df.groupby(['departement']).mean().sort_values('prix_par_m2_max')

# %%
df_max = df.groupby(['departement']).mean().sort_values('prix_par_m2_max')
df_max = df_max.loc[(df_max['prix_par_m2_min']>1)]

# %%
df_max['departement'] = df_max.index #je crée une colonne qui correspond à l'index (la colonne regions)

# %%
sns.barplot(y='departement', x='prix_par_m2_max', data=df_max, width= 0.2, orient="h").set_title('prix_par_m2_max')#OK

# %% [markdown]
# ## Ajout de la colonne 'prix_par_m2_mean'(qui correspond à la moyenne des loyers des logements porposés)

# %%
df['prix_par_m2_mean'] = df['Mean Loyer']/df['Mean Surface'] # On crée une nouvelle variable prix_par_m2_mean

# %%
df_mean = df.groupby(['departement']).mean().sort_values('prix_par_m2_mean')
df_mean = df_mean.loc[(df_mean['prix_par_m2_mean']>1)] 
df_mean.columns
df_mean['departement'] = df_mean.index #je crée une colonne qui correspond à l'index (la colonne regions)
sns.barplot(y='departement', x='prix_par_m2_mean', data= df_mean, width= 0.2, orient="h").set_title('prix_par_m2_mean')#OK

# %% [markdown]
# ## Construction de graphes pour surfaces min et max

# %%
df_surface_min = df.groupby(['departement']).mean().sort_values('Min Surface')
df_surface_min

# %%
df_surface_min.columns
df_surface_min['departement'] = df_surface_min.index #je crée une colonne qui correspond à l'index (la colonne regions)
sns.barplot(y='departement', x='Min Surface', data= df_surface_min, width= 0.2, orient="h").set_title('Min Surface')#OK

# %%
df_surface_max = df.groupby(['departement']).mean().sort_values('Max Surface')
df_surface_max

# %%
df_surface_max.columns
df_surface_max['departement'] = df_surface_max.index #je crée une colonne qui correspond à l'index (la colonne regions)
sns.barplot(y='departement', x='Max Surface', data= df_surface_max, width= 0.2, orient="h").set_title('Max Surface')#OK

# %% [markdown]
# ## Compter le nombre de residence Crous par région

# %%
df['comptage_résidence']= 1
df.head(5)
df_nb_res = df.groupby(['departement']).sum().sort_values('comptage_résidence', ascending = False)

df_nb_res['departement'] = df_nb_res.index #je crée une colonne qui correspond à l'index (la colonne regions)
sns.barplot(y='departement', x='comptage_résidence', data= df_nb_res, width= 0.2, orient="h").set_title('Nombre de résidence par départements')#OK

# %% [markdown]
# ## 2.2 La France des Crous
#
# On retire les territoires et régions d'Outre-Mer pour réaliser des carte

# %%
df_metro = df[ (df["regions"] != "La Réunion") &

                    (df["regions"] != "Guadeloupe") &

                    (df["regions"] != "Martinique") &

                    (df["regions"] != "Guyane")]

df_metro.reset_index(inplace = True)

# %% [markdown]
# ### 2.2.1 Classical maps

# %%
"""
On récupère un fond de carte de la France.
"""

France = gpd.read_file("https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/france.geojson")

# %%
fig, ax = plt.subplots(figsize=(24, 18))
France.plot(ax =ax, edgecolor='darkgrey', facecolor='lightgrey')

df_metro.plot(ax = ax, color='red')

# %% [markdown]
# ### 2.2.2. Interactive maps

# %%
map = folium.Map(location=[48.7144587, 2.2453842], tiles="OpenStreetMap", zoom_start=11)

# Create a geometry list from the GeoDataFrame

geo_df_list = [[point.xy[1][0], point.xy[0][0]] for point in df_metro.geometry] 


# Iterate through list and add a marker for each residence, color-coded by its type.

i = 0

for coordinates in geo_df_list:

    # Place the markers with the popup labels and data

    map.add_child(

        folium.Marker(

            location=coordinates,

            popup=

                 "Name: " + str(df_metro.title[i]) + "<br>"

                + "Moyenne Loyer: " + str(df_metro["Mean Loyer"][i]) + "<br>"

                + "Moyenne surface: " + str(df_metro["Mean Surface"][i]) + "<br>"

                + "Address: " + str(df_metro.address[i]) + "<br>"

                + "Coordinates: " + str(geo_df_list[i])

            ,

        

            icon=folium.Icon(color="blue"),

        )

    )

    i = i + 1

map

# %% [markdown]
# ### 2.2.3 cartes statistiques

# %%
gdf_mean = df_metro.groupby(['departement']).mean().sort_values('prix_par_m2_mean')
gdf_mean['departement'] = gdf_mean.index

# %%
gpd_mean = gpd.GeoDataFrame(gdf_mean.set_index('departement').join(gdf_dep.set_index('departement')))

# %%
gpd_mean_wout_nan = gpd_mean[gpd_mean['prix_par_m2_mean'] > 1]

# %%
fig, ax = plt.subplots(figsize=(24, 18))
France.plot(ax =ax, edgecolor='darkgrey', facecolor='lightgrey')

# Set up the color sheme:
import mapclassify as mc
scheme = mc.Quantiles(gpd_mean_wout_nan['prix_par_m2_mean'], k=10)

# Map
gplt.choropleth(gpd_mean_wout_nan, 
    hue="prix_par_m2_mean", 
    linewidth=.1,
    scheme=scheme, cmap='inferno_r',
    legend=True,
    edgecolor='black',
    ax=ax
                
);

ax.set_title('Mean crous rent in french departements', fontsize=13);

# %%
fig, ax = plt.subplots(figsize=(24, 18))
France.plot(ax =ax, edgecolor='darkgrey', facecolor='lightgrey')

# Set up the color sheme:
import mapclassify as mc
scheme = mc.Quantiles(gpd_mean_wout_nan['prix_par_m2_mean'], k=10)

# Map
gplt.choropleth(gpd_mean_wout_nan, 
    hue="prix_par_m2_mean", 
    linewidth=.1,
    scheme=scheme, cmap='inferno_r',
    legend=True,
    edgecolor='black',
    ax=ax
);
ax.set_title('Mean crous rent in french "departements" with residences', fontsize=13)

df_metro.plot(ax = ax, color='green');
