# %%
# !pip install geoplot
# !pip install contextily
# !pip install altair
# Out:
# Collecting geoplot
#   Downloading geoplot-0.5.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: seaborn in /opt/mamba/lib/python3.10/site-packages (from geoplot) (0.12.1)
# Requirement already satisfied: geopandas>=0.9.0 in /opt/mamba/lib/python3.10/site-packages (from geoplot) (0.12.1)
# Requirement already satisfied: pandas in /opt/mamba/lib/python3.10/site-packages (from geoplot) (1.5.1)
# Collecting cartopy
#   Downloading Cartopy-0.21.0.tar.gz (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 17.6 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib>=3.1.2 in /opt/mamba/lib/python3.10/site-packages (from geoplot) (3.6.2)
# Requirement already satisfied: mapclassify>=2.1 in /opt/mamba/lib/python3.10/site-packages (from geoplot) (2.4.3)
# Collecting contextily>=1.0.0
#   Downloading contextily-1.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: xyzservices in /opt/mamba/lib/python3.10/site-packages (from contextily>=1.0.0->geoplot) (2022.9.0)
# Collecting mercantile
#   Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Collecting rasterio
#   Downloading rasterio-1.3.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 10.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests in /opt/mamba/lib/python3.10/site-packages (from contextily>=1.0.0->geoplot) (2.28.1)
# Requirement already satisfied: pillow in /opt/mamba/lib/python3.10/site-packages (from contextily>=1.0.0->geoplot) (9.2.0)
# Requirement already satisfied: joblib in /opt/mamba/lib/python3.10/site-packages (from contextily>=1.0.0->geoplot) (1.2.0)
# Collecting geopy
#   Downloading geopy-2.3.0-py3-none-any.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 kB 18.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /opt/mamba/lib/python3.10/site-packages (from geopandas>=0.9.0->geoplot) (21.3)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /opt/mamba/lib/python3.10/site-packages (from geopandas>=0.9.0->geoplot) (3.4.0)
# Requirement already satisfied: fiona>=1.8 in /opt/mamba/lib/python3.10/site-packages (from geopandas>=0.9.0->geoplot) (1.8.22)
# Requirement already satisfied: shapely>=1.7 in /opt/mamba/lib/python3.10/site-packages (from geopandas>=0.9.0->geoplot) (1.8.5.post1)
# Requirement already satisfied: networkx in /opt/mamba/lib/python3.10/site-packages (from mapclassify>=2.1->geoplot) (2.8.8)
# Requirement already satisfied: scipy>=1.0 in /opt/mamba/lib/python3.10/site-packages (from mapclassify>=2.1->geoplot) (1.9.3)
# Requirement already satisfied: scikit-learn in /opt/mamba/lib/python3.10/site-packages (from mapclassify>=2.1->geoplot) (1.1.3)
# Requirement already satisfied: numpy>=1.3 in /opt/mamba/lib/python3.10/site-packages (from mapclassify>=2.1->geoplot) (1.23.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/mamba/lib/python3.10/site-packages (from matplotlib>=3.1.2->geoplot) (1.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/mamba/lib/python3.10/site-packages (from matplotlib>=3.1.2->geoplot) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /opt/mamba/lib/python3.10/site-packages (from matplotlib>=3.1.2->geoplot) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/mamba/lib/python3.10/site-packages (from matplotlib>=3.1.2->geoplot) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/mamba/lib/python3.10/site-packages (from matplotlib>=3.1.2->geoplot) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/mamba/lib/python3.10/site-packages (from matplotlib>=3.1.2->geoplot) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/mamba/lib/python3.10/site-packages (from pandas->geoplot) (2022.6)
# Collecting pyshp>=2.1
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: cligj>=0.5 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas>=0.9.0->geoplot) (0.7.2)
# Requirement already satisfied: setuptools in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas>=0.9.0->geoplot) (65.5.1)
# Requirement already satisfied: click>=4.0 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas>=0.9.0->geoplot) (8.1.3)
# Requirement already satisfied: six>=1.7 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas>=0.9.0->geoplot) (1.16.0)
# Requirement already satisfied: click-plugins>=1.0 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas>=0.9.0->geoplot) (1.1.1)
# Requirement already satisfied: certifi in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas>=0.9.0->geoplot) (2022.9.24)
# Requirement already satisfied: attrs>=17 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas>=0.9.0->geoplot) (22.1.0)
# Requirement already satisfied: munch in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas>=0.9.0->geoplot) (2.5.0)
# Collecting geographiclib<3,>=1.52
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 12.8 MB/s eta 0:00:00
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting affine
#   Downloading affine-2.3.1-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/mamba/lib/python3.10/site-packages (from requests->contextily>=1.0.0->geoplot) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /opt/mamba/lib/python3.10/site-packages (from requests->contextily>=1.0.0->geoplot) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/mamba/lib/python3.10/site-packages (from requests->contextily>=1.0.0->geoplot) (2.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/mamba/lib/python3.10/site-packages (from scikit-learn->mapclassify>=2.1->geoplot) (3.1.0)
# Building wheels for collected packages: cartopy
#   Building wheel for cartopy (pyproject.toml) ... done
#   Created wheel for cartopy: filename=Cartopy-0.21.0-cp310-cp310-linux_x86_64.whl size=10809020 sha256=d8c4bf575ae5b80d97956342633e44a6f060839d8233981f9c7dde97fa119046
#   Stored in directory: /home/onyxia/.cache/pip/wheels/e3/fd/ba/000a64d1895b47e50364ac8ba24f00d682b26f989549f9979d
# Successfully built cartopy
# Installing collected packages: affine, snuggs, pyshp, mercantile, geographiclib, rasterio, geopy, contextily, cartopy, geoplot
# Successfully installed affine-2.3.1 cartopy-0.21.0 contextily-1.2.0 geographiclib-2.0 geoplot-0.5.1 geopy-2.3.0 mercantile-1.2.1 pyshp-2.3.1 rasterio-1.3.4 snuggs-1.4.7
# Requirement already satisfied: contextily in /opt/mamba/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: pillow in /opt/mamba/lib/python3.10/site-packages (from contextily) (9.2.0)
# Requirement already satisfied: requests in /opt/mamba/lib/python3.10/site-packages (from contextily) (2.28.1)
# Requirement already satisfied: geopy in /opt/mamba/lib/python3.10/site-packages (from contextily) (2.3.0)
# Requirement already satisfied: matplotlib in /opt/mamba/lib/python3.10/site-packages (from contextily) (3.6.2)
# Requirement already satisfied: rasterio in /opt/mamba/lib/python3.10/site-packages (from contextily) (1.3.4)
# Requirement already satisfied: mercantile in /opt/mamba/lib/python3.10/site-packages (from contextily) (1.2.1)
# Requirement already satisfied: xyzservices in /opt/mamba/lib/python3.10/site-packages (from contextily) (2022.9.0)
# Requirement already satisfied: joblib in /opt/mamba/lib/python3.10/site-packages (from contextily) (1.2.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/mamba/lib/python3.10/site-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->contextily) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->contextily) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->contextily) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->contextily) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->contextily) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->contextily) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: numpy>=1.19 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->contextily) (1.23.5)
# Requirement already satisfied: click>=3.0 in /opt/mamba/lib/python3.10/site-packages (from mercantile->contextily) (8.1.3)
# Requirement already satisfied: snuggs>=1.4.1 in /opt/mamba/lib/python3.10/site-packages (from rasterio->contextily) (1.4.7)
# Requirement already satisfied: cligj>=0.5 in /opt/mamba/lib/python3.10/site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: click-plugins in /opt/mamba/lib/python3.10/site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: attrs in /opt/mamba/lib/python3.10/site-packages (from rasterio->contextily) (22.1.0)
# Requirement already satisfied: affine in /opt/mamba/lib/python3.10/site-packages (from rasterio->contextily) (2.3.1)
# Requirement already satisfied: setuptools in /opt/mamba/lib/python3.10/site-packages (from rasterio->contextily) (65.5.1)
# Requirement already satisfied: certifi in /opt/mamba/lib/python3.10/site-packages (from rasterio->contextily) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/mamba/lib/python3.10/site-packages (from requests->contextily) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/mamba/lib/python3.10/site-packages (from requests->contextily) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/mamba/lib/python3.10/site-packages (from requests->contextily) (3.4)
# Requirement already satisfied: six>=1.5 in /opt/mamba/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Collecting altair
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.8/812.8 kB 14.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pandas>=0.18 in /opt/mamba/lib/python3.10/site-packages (from altair) (1.5.1)
# Requirement already satisfied: jinja2 in /opt/mamba/lib/python3.10/site-packages (from altair) (3.1.2)
# Requirement already satisfied: entrypoints in /opt/mamba/lib/python3.10/site-packages (from altair) (0.4)
# Requirement already satisfied: toolz in /opt/mamba/lib/python3.10/site-packages (from altair) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /opt/mamba/lib/python3.10/site-packages (from altair) (4.17.0)
# Requirement already satisfied: numpy in /opt/mamba/lib/python3.10/site-packages (from altair) (1.23.5)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/mamba/lib/python3.10/site-packages (from jsonschema>=3.0->altair) (0.19.2)
# Requirement already satisfied: attrs>=17.4.0 in /opt/mamba/lib/python3.10/site-packages (from jsonschema>=3.0->altair) (22.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/mamba/lib/python3.10/site-packages (from pandas>=0.18->altair) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/mamba/lib/python3.10/site-packages (from pandas>=0.18->altair) (2022.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/mamba/lib/python3.10/site-packages (from jinja2->altair) (2.1.1)
# Requirement already satisfied: six>=1.5 in /opt/mamba/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=0.18->altair) (1.16.0)
# Installing collected packages: altair
# Successfully installed altair-4.2.0

# %%
import pandas as pd 
import geopandas as gpd 
import nltk
nltk.download('punkt')
import contextily as ctx
import geoplot as gplt
import geoplot.crs as gcrs
import matplotlib.pyplot as plt
import folium
import numpy as np
import seaborn as sns
import altair as alt
# Out:
# [nltk_data] Downloading package punkt to /home/onyxia/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Part I : Obtention du dataframe
# ## 1.1.Récupération des loyers, des surfaces et de la localisation des résidences

# %%
df = pd.read_csv("fr_crous_logement_france_entiere.csv", sep =';')

# %%
df = df[["title", "infos", "address" ,"geocalisation", "regions"]]

# %%
from functions_for_data_cleaning import *

df = get_loyer(df)
df = get_surface(df)
df = get_localisation(df) 
df
# Out:
# /home/onyxia/work/Immobilier-etudiant-/functions_for_data_cleaning.py:218: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Surface'][j] = remove(df['Surface'][j], 7, 100)
#                                                  title  \
# 0                                     Résidence Vauban
# 1                   Résidence Le Square de l'Echiquier
# 2                         Résidence Les Bas Longchamps
# 3                                   Résidence de l’Ile
# 4                               Résidence La Pacaterie
# ..                                                 ...
# 783  Cité Grémillon (secteur d'Hérouville-Saint-Clair)
# 784                           Résidence Antide Janvier
# 785                         Résidence Jean Paul Sartre
# 786                                              Maret
# 787                                          Antipodes
#
#                                                  infos  \
# 0    Description La résidence est située au cœur de...
# 1    DescriptionRésidence universitaire nouvellemen...
# 2    Description Résidence universitaire située à p...
# 3    Description Résidence universitaire située à p...
# 4    Description Résidence universitaire longée par...
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784  Localisation :\r\n Au centre ville, à proximit...
# 785  Localisation :\r\n La résidence Sartre est sit...
# 786                                                NaN
# 787  La résidence compte 350 logements (du T1 au T3...
#
#                                                address  \
# 0              1 boulevard d’Alembert 78280 Guyancourt
# 1         9 square de l'échiquier 95800 Cergy-Pontoise
# 2                  2 rue Abraham Lincoln 92220 Bagneux
# 3    14 rue du Docteur Collé - bâtiment 227 du camp...
# 4       Bâtiment 499 - rue de la Pacaterie 91400 Orsay
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784                6 rue Antide Janvier 25000 Besançon
# 785                   Rue Gaston Deferre 90000 Belfort
# 786                3 rue du Docteur Maret  21000 Dijon
# 787                24/32 rue Alain Savary  21000 Dijon
#
#                    geocalisation                  regions  \
# 0     48.7796516418,2.0441513062            Île-de-France
# 1       49.0482978821,2.02688694            Île-de-France
# 2     48.7906913757,2.3169708252            Île-de-France
# 3      48.698802948,2.1578958035            Île-de-France
# 4     48.7015419006,2.1846776009            Île-de-France
# ..                           ...                      ...
# 783  49.2032051086,-0.3392136097                Normandie
# 784   47.2365074158,6.0153431892  Bourgogne-Franche-Comté
# 785   47.6389884949,6.8537139893  Bourgogne-Franche-Comté
# 786   47.3224983215,5.0353322029  Bourgogne-Franche-Comté
# 787   47.3101768494,5.0722389221  Bourgogne-Franche-Comté
#
#                                                  Loyer  Max Loyer  Min Loyer  \
# 0                                       [333.0, 537.0]     537.00     333.00
# 1                                              [334.0]     334.00     334.00
# 2                                       [332.0, 359.0]     359.00     332.00
# 3                                              [362.0]     362.00     362.00
# 4                                              [154.0]     154.00     154.00
# ..                                                 ...        ...        ...
# 783       [249.85, 312.9, 388.6, 467.4, 525.0, 556.14]     556.14     249.85
# 784                              [347.0, 502.0, 523.0]     523.00     347.00
# 785  [280.0, 311.0, 361.0, 405.0, 416.0, 466.0, 586.0]     586.00     280.00
# 786                                               None        NaN        NaN
# 787                                                 []        NaN        NaN
#
#      Mean Loyer                              Surface  Max Surface  \
# 0    435.000000                                   []          NaN
# 1    334.000000                                   []          NaN
# 2    345.500000                               [28.0]         28.0
# 3    362.000000                               [18.0]         18.0
# 4    154.000000                                   []          NaN
# ..          ...                                  ...          ...
# 783  416.648333  [9.0, 18.0, 30.0, 49.0, 65.0, 69.0]         69.0
# 784  457.333333                         [19.0, 35.3]         35.3
# 785  403.571429                   [18.0, 36.0, 51.5]         51.5
# 786         NaN                                 None          NaN
# 787         NaN                                   []          NaN
#
#      Min Surface  Mean Surface  Longitude   Latitude  \
# 0            NaN           NaN   2.044151  48.779652
# 1            NaN           NaN   2.026887  49.048298
# 2           28.0     28.000000   2.316971  48.790691
# 3           18.0     18.000000   2.157896  48.698803
# 4            NaN           NaN   2.184678  48.701542
# ..           ...           ...        ...        ...
# 783          9.0     40.000000  -0.339214  49.203205
# 784         19.0     27.150000   6.015343  47.236507
# 785         18.0     35.166667   6.853714  47.638988
# 786          NaN           NaN   5.035332  47.322498
# 787          NaN           NaN   5.072239  47.310177
#
#                       geometry
# 0     POINT (2.04415 48.77965)
# 1     POINT (2.02689 49.04830)
# 2     POINT (2.31697 48.79069)
# 3     POINT (2.15790 48.69880)
# 4     POINT (2.18468 48.70154)
# ..                         ...
# 783  POINT (-0.33921 49.20321)
# 784   POINT (6.01534 47.23651)
# 785   POINT (6.85371 47.63899)
# 786   POINT (5.03533 47.32250)
# 787   POINT (5.07224 47.31018)
#
# [788 rows x 16 columns]

# %% [markdown]
# ## 1.2.Récupération des loyers privés des communes (avec la géolocalisation des communes)

# %%
df_private = pd.read_csv("https://www.data.gouv.fr/fr/datasets/r/8fac6fb7-cd07-4747-8e0b-b101c476f0da", encoding= 'unicode_escape', sep = ";")

# %% [markdown]
# On ne garde que le code INSEE, le nom de la ville et le loyer supérieur par m^2

# %%
df_private = df_private[["INSEE", "LIBGEO","upr.IPm2"]]

# %% [markdown]
# On renomme la colonne INSEE en codgeo pour pouvoir la merger avec la carte des contours des villes.

# %%
df_private.rename(columns = {'INSEE':'codgeo'}, inplace = True)

# %%
"""
On rajoute un 0 devant le code INSEE quand il ne fait que quatre chiffres (pour uniformiser avec l'autre base).
"""
for i in range(0,df_private.shape[0]):
    if  len(df_private["codgeo"][i]) == 4: 
            df_private["codgeo"][i] = "0" +  df_private["codgeo"][i]

# %%
df_private = df_private.set_index('codgeo') #on réindex le dataframe avec le code INSEE pour merger après.

# %% [markdown]
# On récuppère les contours géographique des communes.(prends du temps)

# %%
gdf_communes_boundaries = gpd.read_file("https://www.data.gouv.fr/fr/datasets/r/e9391593-fa95-4153-aabe-87ca84d197e9")

# %% [markdown]
# On ne garde que le code INSEE et les données polygoniales.

# %%
gdf_communes_boundaries.rename(columns = {'INSEE_COM':'codgeo'}, inplace = True)
gdf_communes_boundaries = gdf_communes_boundaries[["codgeo", "geometry"]]
gdf_communes_boundaries = gdf_communes_boundaries.set_index('codgeo')

# %% [markdown]
# On concatène les deux datafarmes

# %%
gdf_private = pd.concat([df_private,gdf_communes_boundaries], axis = 1, join = "inner")

# %% [markdown]
# ## 1.3. Jointures spatiales

# %%
#gdf_private['geometry'] = gdf_private['geometry'].apply(wkt.loads) #on transforme en format wkt (sinon ça ne marche pas)
gdf_private = gpd.GeoDataFrame(gdf_private)  #on transforme en geodataframe 
df = gpd.sjoin(df, gdf_private, how='left', op='within') #on réalise la jointure à gauche avec within 
#i.e si le point est dans le polynôme.
# Out:
# /opt/mamba/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3373: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /tmp/ipykernel_194/2580680376.py:3: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   df = gpd.sjoin(df, gdf_private, how='left', op='within') #on réalise la jointure à gauche avec within

# %%
del df['index_right'] #on supprime l'index right pour la prochaine jointure
df
# Out:
#                                                  title  \
# 0                                     Résidence Vauban
# 1                   Résidence Le Square de l'Echiquier
# 2                         Résidence Les Bas Longchamps
# 3                                   Résidence de l’Ile
# 4                               Résidence La Pacaterie
# ..                                                 ...
# 783  Cité Grémillon (secteur d'Hérouville-Saint-Clair)
# 784                           Résidence Antide Janvier
# 785                         Résidence Jean Paul Sartre
# 786                                              Maret
# 787                                          Antipodes
#
#                                                  infos  \
# 0    Description La résidence est située au cœur de...
# 1    DescriptionRésidence universitaire nouvellemen...
# 2    Description Résidence universitaire située à p...
# 3    Description Résidence universitaire située à p...
# 4    Description Résidence universitaire longée par...
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784  Localisation :\r\n Au centre ville, à proximit...
# 785  Localisation :\r\n La résidence Sartre est sit...
# 786                                                NaN
# 787  La résidence compte 350 logements (du T1 au T3...
#
#                                                address  \
# 0              1 boulevard d’Alembert 78280 Guyancourt
# 1         9 square de l'échiquier 95800 Cergy-Pontoise
# 2                  2 rue Abraham Lincoln 92220 Bagneux
# 3    14 rue du Docteur Collé - bâtiment 227 du camp...
# 4       Bâtiment 499 - rue de la Pacaterie 91400 Orsay
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784                6 rue Antide Janvier 25000 Besançon
# 785                   Rue Gaston Deferre 90000 Belfort
# 786                3 rue du Docteur Maret  21000 Dijon
# 787                24/32 rue Alain Savary  21000 Dijon
#
#                    geocalisation                  regions  \
# 0     48.7796516418,2.0441513062            Île-de-France
# 1       49.0482978821,2.02688694            Île-de-France
# 2     48.7906913757,2.3169708252            Île-de-France
# 3      48.698802948,2.1578958035            Île-de-France
# 4     48.7015419006,2.1846776009            Île-de-France
# ..                           ...                      ...
# 783  49.2032051086,-0.3392136097                Normandie
# 784   47.2365074158,6.0153431892  Bourgogne-Franche-Comté
# 785   47.6389884949,6.8537139893  Bourgogne-Franche-Comté
# 786   47.3224983215,5.0353322029  Bourgogne-Franche-Comté
# 787   47.3101768494,5.0722389221  Bourgogne-Franche-Comté
#
#                                                  Loyer  Max Loyer  Min Loyer  \
# 0                                       [333.0, 537.0]     537.00     333.00
# 1                                              [334.0]     334.00     334.00
# 2                                       [332.0, 359.0]     359.00     332.00
# 3                                              [362.0]     362.00     362.00
# 4                                              [154.0]     154.00     154.00
# ..                                                 ...        ...        ...
# 783       [249.85, 312.9, 388.6, 467.4, 525.0, 556.14]     556.14     249.85
# 784                              [347.0, 502.0, 523.0]     523.00     347.00
# 785  [280.0, 311.0, 361.0, 405.0, 416.0, 466.0, 586.0]     586.00     280.00
# 786                                               None        NaN        NaN
# 787                                                 []        NaN        NaN
#
#      Mean Loyer                              Surface  Max Surface  \
# 0    435.000000                                   []          NaN
# 1    334.000000                                   []          NaN
# 2    345.500000                               [28.0]         28.0
# 3    362.000000                               [18.0]         18.0
# 4    154.000000                                   []          NaN
# ..          ...                                  ...          ...
# 783  416.648333  [9.0, 18.0, 30.0, 49.0, 65.0, 69.0]         69.0
# 784  457.333333                         [19.0, 35.3]         35.3
# 785  403.571429                   [18.0, 36.0, 51.5]         51.5
# 786         NaN                                 None          NaN
# 787         NaN                                   []          NaN
#
#      Min Surface  Mean Surface  Longitude   Latitude  \
# 0            NaN           NaN   2.044151  48.779652
# 1            NaN           NaN   2.026887  49.048298
# 2           28.0     28.000000   2.316971  48.790691
# 3           18.0     18.000000   2.157896  48.698803
# 4            NaN           NaN   2.184678  48.701542
# ..           ...           ...        ...        ...
# 783          9.0     40.000000  -0.339214  49.203205
# 784         19.0     27.150000   6.015343  47.236507
# 785         18.0     35.166667   6.853714  47.638988
# 786          NaN           NaN   5.035332  47.322498
# 787          NaN           NaN   5.072239  47.310177
#
#                       geometry                  LIBGEO     upr.IPm2
# 0     POINT (2.04415 48.77965)              Guyancourt  21,73842264
# 1     POINT (2.02689 49.04830)                   Cergy  20,65371054
# 2     POINT (2.31697 48.79069)                 Bagneux  24,98281618
# 3     POINT (2.15790 48.69880)        Bures-sur-Yvette   21,2713506
# 4     POINT (2.18468 48.70154)                   Orsay  21,07028697
# ..                         ...                     ...          ...
# 783  POINT (-0.33921 49.20321)  Hérouville-Saint-Clair  13,70540711
# 784   POINT (6.01534 47.23651)                Besançon  13,92609502
# 785   POINT (6.85371 47.63899)                 Belfort  13,04684054
# 786   POINT (5.03533 47.32250)                   Dijon  14,38634283
# 787   POINT (5.07224 47.31018)                   Dijon  14,38634283
#
# [788 rows x 18 columns]

# %% [markdown]
# ## 1.4 Ajout des départements

# %%
gdf_dep = gpd.read_file("https://www.data.gouv.fr/fr/datasets/r/eb36371a-761d-44a8-93ec-3d728bec17ce")
gdf_dep.rename(columns = {'nom':'departement'}, inplace = True)
gdf_dep = gdf_dep[["departement", "geometry"]]
gdf_dep
# Out:
#           departement                                           geometry
# 0          La Réunion  MULTIPOLYGON (((55.21643 -21.03904, 55.21652 -...
# 1                Aude  POLYGON ((1.68872 43.27368, 1.69001 43.27423, ...
# 2         Haute-Loire  POLYGON ((3.08206 45.28988, 3.08209 45.29031, ...
# 3    Bouches-du-Rhône  MULTIPOLYGON (((4.23014 43.46047, 4.23025 43.4...
# 4      Lot-et-Garonne  POLYGON ((-0.14058 44.22648, -0.12931 44.23218...
# ..                ...                                                ...
# 97           Morbihan  MULTIPOLYGON (((-3.73508 48.11140, -3.73507 48...
# 98              Doubs  POLYGON ((5.69876 47.26464, 5.69877 47.26481, ...
# 99               Jura  MULTIPOLYGON (((5.25202 46.94451, 5.25208 46.9...
# 100           Ardèche  POLYGON ((3.86110 44.71118, 3.86110 44.71151, ...
# 101              Gard  POLYGON ((3.26190 44.09335, 3.26221 44.09389, ...
#
# [102 rows x 2 columns]

# %%
df = gpd.sjoin(df, gdf_dep, how='left', op='within')
# Out:
# /opt/mamba/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3373: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /tmp/ipykernel_194/3352756710.py:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   df = gpd.sjoin(df, gdf_dep, how='left', op='within')

# %%
df
# Out:
#                                                  title  \
# 0                                     Résidence Vauban
# 1                   Résidence Le Square de l'Echiquier
# 2                         Résidence Les Bas Longchamps
# 3                                   Résidence de l’Ile
# 4                               Résidence La Pacaterie
# ..                                                 ...
# 783  Cité Grémillon (secteur d'Hérouville-Saint-Clair)
# 784                           Résidence Antide Janvier
# 785                         Résidence Jean Paul Sartre
# 786                                              Maret
# 787                                          Antipodes
#
#                                                  infos  \
# 0    Description La résidence est située au cœur de...
# 1    DescriptionRésidence universitaire nouvellemen...
# 2    Description Résidence universitaire située à p...
# 3    Description Résidence universitaire située à p...
# 4    Description Résidence universitaire longée par...
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784  Localisation :\r\n Au centre ville, à proximit...
# 785  Localisation :\r\n La résidence Sartre est sit...
# 786                                                NaN
# 787  La résidence compte 350 logements (du T1 au T3...
#
#                                                address  \
# 0              1 boulevard d’Alembert 78280 Guyancourt
# 1         9 square de l'échiquier 95800 Cergy-Pontoise
# 2                  2 rue Abraham Lincoln 92220 Bagneux
# 3    14 rue du Docteur Collé - bâtiment 227 du camp...
# 4       Bâtiment 499 - rue de la Pacaterie 91400 Orsay
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784                6 rue Antide Janvier 25000 Besançon
# 785                   Rue Gaston Deferre 90000 Belfort
# 786                3 rue du Docteur Maret  21000 Dijon
# 787                24/32 rue Alain Savary  21000 Dijon
#
#                    geocalisation                  regions  \
# 0     48.7796516418,2.0441513062            Île-de-France
# 1       49.0482978821,2.02688694            Île-de-France
# 2     48.7906913757,2.3169708252            Île-de-France
# 3      48.698802948,2.1578958035            Île-de-France
# 4     48.7015419006,2.1846776009            Île-de-France
# ..                           ...                      ...
# 783  49.2032051086,-0.3392136097                Normandie
# 784   47.2365074158,6.0153431892  Bourgogne-Franche-Comté
# 785   47.6389884949,6.8537139893  Bourgogne-Franche-Comté
# 786   47.3224983215,5.0353322029  Bourgogne-Franche-Comté
# 787   47.3101768494,5.0722389221  Bourgogne-Franche-Comté
#
#                                                  Loyer  Max Loyer  Min Loyer  \
# 0                                       [333.0, 537.0]     537.00     333.00
# 1                                              [334.0]     334.00     334.00
# 2                                       [332.0, 359.0]     359.00     332.00
# 3                                              [362.0]     362.00     362.00
# 4                                              [154.0]     154.00     154.00
# ..                                                 ...        ...        ...
# 783       [249.85, 312.9, 388.6, 467.4, 525.0, 556.14]     556.14     249.85
# 784                              [347.0, 502.0, 523.0]     523.00     347.00
# 785  [280.0, 311.0, 361.0, 405.0, 416.0, 466.0, 586.0]     586.00     280.00
# 786                                               None        NaN        NaN
# 787                                                 []        NaN        NaN
#
#      Mean Loyer                              Surface  Max Surface  \
# 0    435.000000                                   []          NaN
# 1    334.000000                                   []          NaN
# 2    345.500000                               [28.0]         28.0
# 3    362.000000                               [18.0]         18.0
# 4    154.000000                                   []          NaN
# ..          ...                                  ...          ...
# 783  416.648333  [9.0, 18.0, 30.0, 49.0, 65.0, 69.0]         69.0
# 784  457.333333                         [19.0, 35.3]         35.3
# 785  403.571429                   [18.0, 36.0, 51.5]         51.5
# 786         NaN                                 None          NaN
# 787         NaN                                   []          NaN
#
#      Min Surface  Mean Surface  Longitude   Latitude  \
# 0            NaN           NaN   2.044151  48.779652
# 1            NaN           NaN   2.026887  49.048298
# 2           28.0     28.000000   2.316971  48.790691
# 3           18.0     18.000000   2.157896  48.698803
# 4            NaN           NaN   2.184678  48.701542
# ..           ...           ...        ...        ...
# 783          9.0     40.000000  -0.339214  49.203205
# 784         19.0     27.150000   6.015343  47.236507
# 785         18.0     35.166667   6.853714  47.638988
# 786          NaN           NaN   5.035332  47.322498
# 787          NaN           NaN   5.072239  47.310177
#
#                       geometry                  LIBGEO     upr.IPm2  \
# 0     POINT (2.04415 48.77965)              Guyancourt  21,73842264
# 1     POINT (2.02689 49.04830)                   Cergy  20,65371054
# 2     POINT (2.31697 48.79069)                 Bagneux  24,98281618
# 3     POINT (2.15790 48.69880)        Bures-sur-Yvette   21,2713506
# 4     POINT (2.18468 48.70154)                   Orsay  21,07028697
# ..                         ...                     ...          ...
# 783  POINT (-0.33921 49.20321)  Hérouville-Saint-Clair  13,70540711
# 784   POINT (6.01534 47.23651)                Besançon  13,92609502
# 785   POINT (6.85371 47.63899)                 Belfort  13,04684054
# 786   POINT (5.03533 47.32250)                   Dijon  14,38634283
# 787   POINT (5.07224 47.31018)                   Dijon  14,38634283
#
#      index_right            departement
# 0             73               Yvelines
# 1             67             Val-d'Oise
# 2             35         Hauts-de-Seine
# 3              8                Essonne
# 4              8                Essonne
# ..           ...                    ...
# 783           69               Calvados
# 784           98                  Doubs
# 785           86  Territoire-de-Belfort
# 786           78              Côte-d'Or
# 787           78              Côte-d'Or
#
# [788 rows x 20 columns]

# %%
del df['index_right'] #on supprime l'index right pour la prochaine jointure
df
# Out:
#                                                  title  \
# 0                                     Résidence Vauban
# 1                   Résidence Le Square de l'Echiquier
# 2                         Résidence Les Bas Longchamps
# 3                                   Résidence de l’Ile
# 4                               Résidence La Pacaterie
# ..                                                 ...
# 783  Cité Grémillon (secteur d'Hérouville-Saint-Clair)
# 784                           Résidence Antide Janvier
# 785                         Résidence Jean Paul Sartre
# 786                                              Maret
# 787                                          Antipodes
#
#                                                  infos  \
# 0    Description La résidence est située au cœur de...
# 1    DescriptionRésidence universitaire nouvellemen...
# 2    Description Résidence universitaire située à p...
# 3    Description Résidence universitaire située à p...
# 4    Description Résidence universitaire longée par...
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784  Localisation :\r\n Au centre ville, à proximit...
# 785  Localisation :\r\n La résidence Sartre est sit...
# 786                                                NaN
# 787  La résidence compte 350 logements (du T1 au T3...
#
#                                                address  \
# 0              1 boulevard d’Alembert 78280 Guyancourt
# 1         9 square de l'échiquier 95800 Cergy-Pontoise
# 2                  2 rue Abraham Lincoln 92220 Bagneux
# 3    14 rue du Docteur Collé - bâtiment 227 du camp...
# 4       Bâtiment 499 - rue de la Pacaterie 91400 Orsay
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784                6 rue Antide Janvier 25000 Besançon
# 785                   Rue Gaston Deferre 90000 Belfort
# 786                3 rue du Docteur Maret  21000 Dijon
# 787                24/32 rue Alain Savary  21000 Dijon
#
#                    geocalisation                  regions  \
# 0     48.7796516418,2.0441513062            Île-de-France
# 1       49.0482978821,2.02688694            Île-de-France
# 2     48.7906913757,2.3169708252            Île-de-France
# 3      48.698802948,2.1578958035            Île-de-France
# 4     48.7015419006,2.1846776009            Île-de-France
# ..                           ...                      ...
# 783  49.2032051086,-0.3392136097                Normandie
# 784   47.2365074158,6.0153431892  Bourgogne-Franche-Comté
# 785   47.6389884949,6.8537139893  Bourgogne-Franche-Comté
# 786   47.3224983215,5.0353322029  Bourgogne-Franche-Comté
# 787   47.3101768494,5.0722389221  Bourgogne-Franche-Comté
#
#                                                  Loyer  Max Loyer  Min Loyer  \
# 0                                       [333.0, 537.0]     537.00     333.00
# 1                                              [334.0]     334.00     334.00
# 2                                       [332.0, 359.0]     359.00     332.00
# 3                                              [362.0]     362.00     362.00
# 4                                              [154.0]     154.00     154.00
# ..                                                 ...        ...        ...
# 783       [249.85, 312.9, 388.6, 467.4, 525.0, 556.14]     556.14     249.85
# 784                              [347.0, 502.0, 523.0]     523.00     347.00
# 785  [280.0, 311.0, 361.0, 405.0, 416.0, 466.0, 586.0]     586.00     280.00
# 786                                               None        NaN        NaN
# 787                                                 []        NaN        NaN
#
#      Mean Loyer                              Surface  Max Surface  \
# 0    435.000000                                   []          NaN
# 1    334.000000                                   []          NaN
# 2    345.500000                               [28.0]         28.0
# 3    362.000000                               [18.0]         18.0
# 4    154.000000                                   []          NaN
# ..          ...                                  ...          ...
# 783  416.648333  [9.0, 18.0, 30.0, 49.0, 65.0, 69.0]         69.0
# 784  457.333333                         [19.0, 35.3]         35.3
# 785  403.571429                   [18.0, 36.0, 51.5]         51.5
# 786         NaN                                 None          NaN
# 787         NaN                                   []          NaN
#
#      Min Surface  Mean Surface  Longitude   Latitude  \
# 0            NaN           NaN   2.044151  48.779652
# 1            NaN           NaN   2.026887  49.048298
# 2           28.0     28.000000   2.316971  48.790691
# 3           18.0     18.000000   2.157896  48.698803
# 4            NaN           NaN   2.184678  48.701542
# ..           ...           ...        ...        ...
# 783          9.0     40.000000  -0.339214  49.203205
# 784         19.0     27.150000   6.015343  47.236507
# 785         18.0     35.166667   6.853714  47.638988
# 786          NaN           NaN   5.035332  47.322498
# 787          NaN           NaN   5.072239  47.310177
#
#                       geometry                  LIBGEO     upr.IPm2  \
# 0     POINT (2.04415 48.77965)              Guyancourt  21,73842264
# 1     POINT (2.02689 49.04830)                   Cergy  20,65371054
# 2     POINT (2.31697 48.79069)                 Bagneux  24,98281618
# 3     POINT (2.15790 48.69880)        Bures-sur-Yvette   21,2713506
# 4     POINT (2.18468 48.70154)                   Orsay  21,07028697
# ..                         ...                     ...          ...
# 783  POINT (-0.33921 49.20321)  Hérouville-Saint-Clair  13,70540711
# 784   POINT (6.01534 47.23651)                Besançon  13,92609502
# 785   POINT (6.85371 47.63899)                 Belfort  13,04684054
# 786   POINT (5.03533 47.32250)                   Dijon  14,38634283
# 787   POINT (5.07224 47.31018)                   Dijon  14,38634283
#
#                departement
# 0                 Yvelines
# 1               Val-d'Oise
# 2           Hauts-de-Seine
# 3                  Essonne
# 4                  Essonne
# ..                     ...
# 783               Calvados
# 784                  Doubs
# 785  Territoire-de-Belfort
# 786              Côte-d'Or
# 787              Côte-d'Or
#
# [788 rows x 19 columns]

# %% [markdown]
# ## 1.5. Association de résidences à une école

# %%
df.crs = "epsg:4326" #on définit la projection de notre dataframe

# %%
"""
Calcul d'un cercle de 20 km autour de la résidence
"""
df1 = df
df1 = df1.to_crs(epsg = 3395) #On prend une projection en mètres
df1['geometry'] = df1['geometry'].buffer(20000) #On prend un rayon de 20km 
df1 = df1.to_crs(4326) #on repasse dans la projection uselle 
df1
# Out:
#                                                  title  \
# 0                                     Résidence Vauban
# 1                   Résidence Le Square de l'Echiquier
# 2                         Résidence Les Bas Longchamps
# 3                                   Résidence de l’Ile
# 4                               Résidence La Pacaterie
# ..                                                 ...
# 783  Cité Grémillon (secteur d'Hérouville-Saint-Clair)
# 784                           Résidence Antide Janvier
# 785                         Résidence Jean Paul Sartre
# 786                                              Maret
# 787                                          Antipodes
#
#                                                  infos  \
# 0    Description La résidence est située au cœur de...
# 1    DescriptionRésidence universitaire nouvellemen...
# 2    Description Résidence universitaire située à p...
# 3    Description Résidence universitaire située à p...
# 4    Description Résidence universitaire longée par...
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784  Localisation :\r\n Au centre ville, à proximit...
# 785  Localisation :\r\n La résidence Sartre est sit...
# 786                                                NaN
# 787  La résidence compte 350 logements (du T1 au T3...
#
#                                                address  \
# 0              1 boulevard d’Alembert 78280 Guyancourt
# 1         9 square de l'échiquier 95800 Cergy-Pontoise
# 2                  2 rue Abraham Lincoln 92220 Bagneux
# 3    14 rue du Docteur Collé - bâtiment 227 du camp...
# 4       Bâtiment 499 - rue de la Pacaterie 91400 Orsay
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784                6 rue Antide Janvier 25000 Besançon
# 785                   Rue Gaston Deferre 90000 Belfort
# 786                3 rue du Docteur Maret  21000 Dijon
# 787                24/32 rue Alain Savary  21000 Dijon
#
#                    geocalisation                  regions  \
# 0     48.7796516418,2.0441513062            Île-de-France
# 1       49.0482978821,2.02688694            Île-de-France
# 2     48.7906913757,2.3169708252            Île-de-France
# 3      48.698802948,2.1578958035            Île-de-France
# 4     48.7015419006,2.1846776009            Île-de-France
# ..                           ...                      ...
# 783  49.2032051086,-0.3392136097                Normandie
# 784   47.2365074158,6.0153431892  Bourgogne-Franche-Comté
# 785   47.6389884949,6.8537139893  Bourgogne-Franche-Comté
# 786   47.3224983215,5.0353322029  Bourgogne-Franche-Comté
# 787   47.3101768494,5.0722389221  Bourgogne-Franche-Comté
#
#                                                  Loyer  Max Loyer  Min Loyer  \
# 0                                       [333.0, 537.0]     537.00     333.00
# 1                                              [334.0]     334.00     334.00
# 2                                       [332.0, 359.0]     359.00     332.00
# 3                                              [362.0]     362.00     362.00
# 4                                              [154.0]     154.00     154.00
# ..                                                 ...        ...        ...
# 783       [249.85, 312.9, 388.6, 467.4, 525.0, 556.14]     556.14     249.85
# 784                              [347.0, 502.0, 523.0]     523.00     347.00
# 785  [280.0, 311.0, 361.0, 405.0, 416.0, 466.0, 586.0]     586.00     280.00
# 786                                               None        NaN        NaN
# 787                                                 []        NaN        NaN
#
#      Mean Loyer                              Surface  Max Surface  \
# 0    435.000000                                   []          NaN
# 1    334.000000                                   []          NaN
# 2    345.500000                               [28.0]         28.0
# 3    362.000000                               [18.0]         18.0
# 4    154.000000                                   []          NaN
# ..          ...                                  ...          ...
# 783  416.648333  [9.0, 18.0, 30.0, 49.0, 65.0, 69.0]         69.0
# 784  457.333333                         [19.0, 35.3]         35.3
# 785  403.571429                   [18.0, 36.0, 51.5]         51.5
# 786         NaN                                 None          NaN
# 787         NaN                                   []          NaN
#
#      Min Surface  Mean Surface  Longitude   Latitude  \
# 0            NaN           NaN   2.044151  48.779652
# 1            NaN           NaN   2.026887  49.048298
# 2           28.0     28.000000   2.316971  48.790691
# 3           18.0     18.000000   2.157896  48.698803
# 4            NaN           NaN   2.184678  48.701542
# ..           ...           ...        ...        ...
# 783          9.0     40.000000  -0.339214  49.203205
# 784         19.0     27.150000   6.015343  47.236507
# 785         18.0     35.166667   6.853714  47.638988
# 786          NaN           NaN   5.035332  47.322498
# 787          NaN           NaN   5.072239  47.310177
#
#                                               geometry  \
# 0    POLYGON ((2.22381 48.77965, 2.22295 48.76801, ...
# 1    POLYGON ((2.20655 49.04830, 2.20568 49.03672, ...
# 2    POLYGON ((2.49663 48.79069, 2.49577 48.77905, ...
# 3    POLYGON ((2.33756 48.69880, 2.33669 48.68714, ...
# 4    POLYGON ((2.36434 48.70154, 2.36348 48.68988, ...
# ..                                                 ...
# 783  POLYGON ((-0.15955 49.20321, -0.16042 49.19166...
# 784  POLYGON ((6.19501 47.23651, 6.19414 47.22451, ...
# 785  POLYGON ((7.03338 47.63899, 7.03251 47.62709, ...
# 786  POLYGON ((5.21500 47.32250, 5.21413 47.31052, ...
# 787  POLYGON ((5.25190 47.31018, 5.25104 47.29820, ...
#
#                      LIBGEO     upr.IPm2            departement
# 0                Guyancourt  21,73842264               Yvelines
# 1                     Cergy  20,65371054             Val-d'Oise
# 2                   Bagneux  24,98281618         Hauts-de-Seine
# 3          Bures-sur-Yvette   21,2713506                Essonne
# 4                     Orsay  21,07028697                Essonne
# ..                      ...          ...                    ...
# 783  Hérouville-Saint-Clair  13,70540711               Calvados
# 784                Besançon  13,92609502                  Doubs
# 785                 Belfort  13,04684054  Territoire-de-Belfort
# 786                   Dijon  14,38634283              Côte-d'Or
# 787                   Dijon  14,38634283              Côte-d'Or
#
# [788 rows x 19 columns]

# %%
"""
Import de notre base de données des écoles 
"""
df_schools = pd.read_csv("https://www.data.gouv.fr/fr/datasets/r/0c713161-26fb-415e-ac1d-8769125f338d", sep = ";")

# %%
df_schools = df_schools[df_schools["annee_universitaire"] == "2021-22" ] #on ne prend que l'année 2021-22
df_schools = df_schools[["etablissement_lib", "effectif_sans_cpge", "etablissement_code_commune", "etablissement_commune"]]

# %%
df_schools
# Out:
#                                       etablissement_lib  effectif_sans_cpge  \
# 427                            Université de Strasbourg               54534
# 428                        Université Toulouse Capitole               17867
# 429   École nationale supérieure des sciences de l'i...                 234
# 430              Université Paris 1 - Panthéon Sorbonne               40413
# 431                     Université Jean Moulin - Lyon 3               25559
# ...                                                 ...                 ...
# 2283  École nationale supérieure de l'électronique e...                 874
# 2284                       Université Paris-Est Créteil               39198
# 2285                           Aix-Marseille Université               71711
# 2286  École nationale supérieure des arts et techniq...                 216
# 2287               Université de la Polynésie Française                3029
#
#      etablissement_code_commune etablissement_commune
# 427                       67482            Strasbourg
# 428                       31555              Toulouse
# 429                       69266          Villeurbanne
# 430                       75105             Paris  5e
# 431                       69387               Lyon 7e
# ...                         ...                   ...
# 2283                      95127                 Cergy
# 2284                      94028               Créteil
# 2285                      13207         Marseille  7e
# 2286                      69385               Lyon 5e
# 2287                      98738              Punaauia
#
# [131 rows x 4 columns]

# %%
df_schools.rename(columns = {'etablissement_code_commune':'codgeo'}, inplace = True) #On renomme la colonne pour la jointure

# %%
index_with_nan = df_schools.index[df_schools.isnull().any(axis=1)]
df_schools.drop(index_with_nan,0, inplace=True) #on enlève les valeurs manquantes
# Out:
# /tmp/ipykernel_194/123655656.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_schools.drop(index_with_nan,0, inplace=True) #on enlève les valeurs manquantes

# %%
df_schools.set_index('codgeo', inplace = True)
df_schools
# Out:
#                                         etablissement_lib  effectif_sans_cpge  \
# codgeo
# 67482                            Université de Strasbourg               54534
# 31555                        Université Toulouse Capitole               17867
# 69266   École nationale supérieure des sciences de l'i...                 234
# 75105              Université Paris 1 - Panthéon Sorbonne               40413
# 69387                     Université Jean Moulin - Lyon 3               25559
# ...                                                   ...                 ...
# 95127   École nationale supérieure de l'électronique e...                 874
# 94028                        Université Paris-Est Créteil               39198
# 13207                            Aix-Marseille Université               71711
# 69385   École nationale supérieure des arts et techniq...                 216
# 98738                Université de la Polynésie Française                3029
#
#        etablissement_commune
# codgeo
# 67482             Strasbourg
# 31555               Toulouse
# 69266           Villeurbanne
# 75105              Paris  5e
# 69387                Lyon 7e
# ...                      ...
# 95127                  Cergy
# 94028                Créteil
# 13207          Marseille  7e
# 69385                Lyon 5e
# 98738               Punaauia
#
# [114 rows x 3 columns]

# %%
df_schools = df_schools.join(gdf_communes_boundaries)
df_schools
# Out:
#                            etablissement_lib  effectif_sans_cpge  \
# codgeo
# 06088                 Université Côte d'Azur               33537
# 10387    Université de technologie de Troyes                3235
# 13001                        Sciences Po Aix                1682
# 13207               Aix-Marseille Université               71711
# 13213                     Centrale Marseille                1165
# ...                                      ...                 ...
# 97302                   Université de Guyane                3890
# 97411               Université de La Réunion               17044
# 97607        Centre universitaire de Mayotte                1335
# 98738   Université de la Polynésie Française                3029
# 98818    Université de la Nouvelle-Calédonie                3621
#
#        etablissement_commune  \
# codgeo
# 06088                   Nice
# 10387                 Troyes
# 13001        Aix-en-Provence
# 13207          Marseille  7e
# 13213          Marseille 13e
# ...                      ...
# 97302                Cayenne
# 97411            Saint-Denis
# 97607                Dembeni
# 98738               Punaauia
# 98818                 Nouméa
#
#                                                  geometry
# codgeo
# 06088   POLYGON ((7.32125 43.72359, 7.32113 43.72360, ...
# 10387   POLYGON ((4.05058 48.29937, 4.05137 48.29921, ...
# 13001   POLYGON ((5.50459 43.53231, 5.50421 43.53234, ...
# 13207   MULTIPOLYGON (((5.28590 43.26396, 5.28588 43.2...
# 13213   POLYGON ((5.41084 43.31492, 5.41150 43.31484, ...
# ...                                                   ...
# 97302   MULTIPOLYGON (((-52.16862 4.88872, -52.16870 4...
# 97411   POLYGON ((55.46906 -21.00973, 55.47105 -21.008...
# 97607   POLYGON ((45.16908 -12.88110, 45.17800 -12.886...
# 98738                                                None
# 98818                                                None
#
# [114 rows x 4 columns]

# %%
df_schools = gpd.GeoDataFrame(df_schools)
df_schools.crs = "epsg:4326"

# %%
"""
essai sur la résidence de Cergy 
"""
a = df_schools.within(df1["geometry"][1])
i = 0 
for element in a : 
    if element == True: 
        print(df_schools['etablissement_lib'][i])
    i = i + 1
# Out:
# CY Cergy Paris Université
# École nationale supérieure de l'électronique et de ses applications de Cergy

# %%
Schools = [] #on crée une liste pour stocker la liste des écoles 
Nbstudents = [] #on crée une liste pour stocker la liste du nombre d'étudiants
Nbstudents_total  = []
for residence in df1["geometry"]: #on prend pour chaque résidence le cercle de 5 km autour de cette résidence
    S = [] #stocke les écoles pour la résidence
    N = [] #idem pour le nb d'étudiants 
    i = 0 #index 
    a = df_schools.within(residence) #On utilise gpd.within qui regarde pour chaque élèment si sa coordonnée est dans le polygone résidence
    for element in a : #on regarde pour chaque élèment de a si l'école est dans le cercle de 5km autour de la résidence
        if element == True: 
            S.append(df_schools['etablissement_lib'][i]) #on ajoute l'école de l'index i 
            N.append(df_schools['effectif_sans_cpge'][i]) #idem pour le nombre d'étudiants
        i = i + 1
    Schools.append(S) 
    Nbstudents.append(N)
    Nbstudents_total.append(sum(N))
df['Schools'] = Schools
df['Nbstudents'] = Nbstudents
df['Nbstudents_total'] = Nbstudents_total
df
# Out:
#                                                  title  \
# 0                                     Résidence Vauban
# 1                   Résidence Le Square de l'Echiquier
# 2                         Résidence Les Bas Longchamps
# 3                                   Résidence de l’Ile
# 4                               Résidence La Pacaterie
# ..                                                 ...
# 783  Cité Grémillon (secteur d'Hérouville-Saint-Clair)
# 784                           Résidence Antide Janvier
# 785                         Résidence Jean Paul Sartre
# 786                                              Maret
# 787                                          Antipodes
#
#                                                  infos  \
# 0    Description La résidence est située au cœur de...
# 1    DescriptionRésidence universitaire nouvellemen...
# 2    Description Résidence universitaire située à p...
# 3    Description Résidence universitaire située à p...
# 4    Description Résidence universitaire longée par...
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784  Localisation :\r\n Au centre ville, à proximit...
# 785  Localisation :\r\n La résidence Sartre est sit...
# 786                                                NaN
# 787  La résidence compte 350 logements (du T1 au T3...
#
#                                                address  \
# 0              1 boulevard d’Alembert 78280 Guyancourt
# 1         9 square de l'échiquier 95800 Cergy-Pontoise
# 2                  2 rue Abraham Lincoln 92220 Bagneux
# 3    14 rue du Docteur Collé - bâtiment 227 du camp...
# 4       Bâtiment 499 - rue de la Pacaterie 91400 Orsay
# ..                                                 ...
# 783  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 784                6 rue Antide Janvier 25000 Besançon
# 785                   Rue Gaston Deferre 90000 Belfort
# 786                3 rue du Docteur Maret  21000 Dijon
# 787                24/32 rue Alain Savary  21000 Dijon
#
#                    geocalisation                  regions  \
# 0     48.7796516418,2.0441513062            Île-de-France
# 1       49.0482978821,2.02688694            Île-de-France
# 2     48.7906913757,2.3169708252            Île-de-France
# 3      48.698802948,2.1578958035            Île-de-France
# 4     48.7015419006,2.1846776009            Île-de-France
# ..                           ...                      ...
# 783  49.2032051086,-0.3392136097                Normandie
# 784   47.2365074158,6.0153431892  Bourgogne-Franche-Comté
# 785   47.6389884949,6.8537139893  Bourgogne-Franche-Comté
# 786   47.3224983215,5.0353322029  Bourgogne-Franche-Comté
# 787   47.3101768494,5.0722389221  Bourgogne-Franche-Comté
#
#                                                  Loyer  Max Loyer  Min Loyer  \
# 0                                       [333.0, 537.0]     537.00     333.00
# 1                                              [334.0]     334.00     334.00
# 2                                       [332.0, 359.0]     359.00     332.00
# 3                                              [362.0]     362.00     362.00
# 4                                              [154.0]     154.00     154.00
# ..                                                 ...        ...        ...
# 783       [249.85, 312.9, 388.6, 467.4, 525.0, 556.14]     556.14     249.85
# 784                              [347.0, 502.0, 523.0]     523.00     347.00
# 785  [280.0, 311.0, 361.0, 405.0, 416.0, 466.0, 586.0]     586.00     280.00
# 786                                               None        NaN        NaN
# 787                                                 []        NaN        NaN
#
#      Mean Loyer                              Surface  ...  Mean Surface  \
# 0    435.000000                                   []  ...           NaN
# 1    334.000000                                   []  ...           NaN
# 2    345.500000                               [28.0]  ...     28.000000
# 3    362.000000                               [18.0]  ...     18.000000
# 4    154.000000                                   []  ...           NaN
# ..          ...                                  ...  ...           ...
# 783  416.648333  [9.0, 18.0, 30.0, 49.0, 65.0, 69.0]  ...     40.000000
# 784  457.333333                         [19.0, 35.3]  ...     27.150000
# 785  403.571429                   [18.0, 36.0, 51.5]  ...     35.166667
# 786         NaN                                 None  ...           NaN
# 787         NaN                                   []  ...           NaN
#
#      Longitude   Latitude                   geometry                  LIBGEO  \
# 0     2.044151  48.779652   POINT (2.04415 48.77965)              Guyancourt
# 1     2.026887  49.048298   POINT (2.02689 49.04830)                   Cergy
# 2     2.316971  48.790691   POINT (2.31697 48.79069)                 Bagneux
# 3     2.157896  48.698803   POINT (2.15790 48.69880)        Bures-sur-Yvette
# 4     2.184678  48.701542   POINT (2.18468 48.70154)                   Orsay
# ..         ...        ...                        ...                     ...
# 783  -0.339214  49.203205  POINT (-0.33921 49.20321)  Hérouville-Saint-Clair
# 784   6.015343  47.236507   POINT (6.01534 47.23651)                Besançon
# 785   6.853714  47.638988   POINT (6.85371 47.63899)                 Belfort
# 786   5.035332  47.322498   POINT (5.03533 47.32250)                   Dijon
# 787   5.072239  47.310177   POINT (5.07224 47.31018)                   Dijon
#
#         upr.IPm2            departement  \
# 0    21,73842264               Yvelines
# 1    20,65371054             Val-d'Oise
# 2    24,98281618         Hauts-de-Seine
# 3     21,2713506                Essonne
# 4    21,07028697                Essonne
# ..           ...                    ...
# 783  13,70540711               Calvados
# 784  13,92609502                  Doubs
# 785  13,04684054  Territoire-de-Belfort
# 786  14,38634283              Côte-d'Or
# 787  14,38634283              Côte-d'Or
#
#                                                Schools  \
# 0    [Université de Versailles Saint-Quentin-en-Yve...
# 1    [CY Cergy Paris Université, École nationale su...
# 2    [Université Paris Lumières, Université Paris 1...
# 3                            [Université Paris-Saclay]
# 4                            [Université Paris-Saclay]
# ..                                                 ...
# 783  [École nationale supérieure d'ingénieurs de Ca...
# 784  [Université Bourgogne - Franche-Comté, École n...
# 785  [Université de technologie de Belfort-Montbéli...
# 786                          [Université de Bourgogne]
# 787                          [Université de Bourgogne]
#
#                                             Nbstudents Nbstudents_total
# 0                                       [14583, 48595]            63178
# 1                                         [26069, 874]            26943
# 2    [78, 40413, 15404, 1937, 22246, 422, 52969, 59...           275639
# 3                                              [48595]            48595
# 4                                              [48595]            48595
# ..                                                 ...              ...
# 783                                       [845, 32088]            32933
# 784                                 [2077, 779, 23578]            26434
# 785                                             [2641]             2641
# 786                                            [31341]            31341
# 787                                            [31341]            31341
#
# [788 rows x 22 columns]

# %% [markdown]
# # II. Visualisation

# %% [markdown]
# ## 2.1 Portrait économique et statistique des résidences

# %%
df['prix_par_m2_min'] = df['Min Loyer']/df['Min Surface'] # On crée une nouvelle variable prix_par_m2_min

# %%
df["upr.IPm2"] = df["upr.IPm2"].apply(lambda x : x.replace(',', '.')) #on remplace les , par des points pour ensuite transformet cette colonne en float

# %%
df["upr.IPm2"] = df["upr.IPm2"].astype(float)

# %%
df3 = df.groupby(['departement']).mean().sort_values('prix_par_m2_min')
# Out:
# /tmp/ipykernel_194/4287470934.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3 = df.groupby(['departement']).mean().sort_values('prix_par_m2_min')

# %% [markdown]
# ## Construction des graphiques

# %%
df2 = df.groupby(['departement']).mean().sort_values('prix_par_m2_min')
df2 = df2.loc[(df2['prix_par_m2_min']>1)]
# Out:
# /tmp/ipykernel_194/2237300556.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2 = df.groupby(['departement']).mean().sort_values('prix_par_m2_min')

# %%
df3['departement'] = df3.index #je crée une colonne qui correspond à l'index (la colonne regions)

# %%
df3 = df.groupby(['departement']).mean().sort_values('prix_par_m2_min')
df3 = df3.loc[(df3['prix_par_m2_min']>1)] 
df3['departement'] = df3.index
df3
# Out:
# /tmp/ipykernel_194/2785515994.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3 = df.groupby(['departement']).mean().sort_values('prix_par_m2_min')
#                         Max Loyer   Min Loyer  Mean Loyer  Max Surface  \
# departement
# Vaucluse               393.535714  246.552857  308.777857    30.087143
# Aisne                  307.750000  261.670000  284.710000    20.700000
# Pyrénées-Orientales    377.166667  313.833333  346.083333    34.000000
# Gard                   413.138333  325.600000  365.063611    40.500000
# Seine-et-Marne         405.333333  318.333333  360.314815    34.000000
# Eure                   385.400000  265.800000  318.800000    45.000000
# Vendée                 329.635000  324.185000  326.910000    28.000000
# Hauts-de-Seine         464.427273  327.236364  394.922727    25.416667
# Hérault                401.296296  299.555556  347.553386    25.216250
# Bouches-du-Rhône       410.341852  252.498889  326.068976    28.186957
# Yvelines               536.000000  374.714286  455.357143    25.502500
# Mayenne                353.160000  308.855000  331.007500    25.955000
# Var                    456.825000  262.775000  357.790625    26.250000
# Ardennes               342.000000  326.750000  334.375000    19.500000
# Moselle                435.494000  319.028000  374.024100    42.300000
# Essonne                376.750000  280.916667  328.833333    19.666667
# Seine-Maritime         365.900000  298.425000  331.336250    24.208333
# Puy-de-Dôme            349.625000  290.718750  319.438542    29.933333
# Somme                  434.973846  305.005385  374.084222    27.420909
# Métropole de Lyon      384.258065  291.193548  334.958871    91.000000
# Vosges                 229.750000  211.250000  221.000000    15.500000
# Seine-Saint-Denis      441.153846  334.692308  383.554487    31.923077
# Guadeloupe             303.666667  296.333333  300.000000    16.555556
# Doubs                  439.333333  302.500000  371.616162    35.966667
# Haute-Corse            358.250000  358.250000  358.250000    16.000000
# Territoire-de-Belfort  424.000000  272.000000  339.523810    36.100000
# Loire-Atlantique       379.009130  290.576087  332.549862    25.782609
# Isère                  388.083333  267.500000  323.847222    12.000000
# Maine-et-Loire         363.537143  299.158571  325.516190    39.245000
# Savoie                 393.800000  298.200000  345.266667    42.200000
# Calvados               428.268750  295.360000  362.774167    35.000000
# Oise                   399.420000  313.754000  362.683533    37.730000
# Val-de-Marne           442.600000  353.800000  399.214286    27.000000
# Sarthe                 352.775000  284.410000  318.592500    24.500000
# Meurthe-et-Moselle     397.027143  267.762857  336.526071    21.071429
# Alpes-Maritimes        446.690000  333.090000  387.366944    31.071429
# Allier                 300.000000  220.200000  260.200000    18.000000
# Bas-Rhin               415.000000  329.000000  373.090909    20.666667
# Paris                  525.153846  394.756410  452.706593    29.406667
# Haut-Rhin              376.250000  342.250000  359.250000    19.000000
# Marne                  366.666667  278.333333  322.611111    16.000000
# Aube                   339.000000  305.666667  324.833333    12.000000
#
#                        Min Surface  Mean Surface  Longitude   Latitude  \
# departement
# Vaucluse                 23.815714     26.951429   4.828818  43.944533
# Aisne                    20.700000     20.700000   3.302897  49.841917
# Pyrénées-Orientales      26.200000     30.100000   2.895255  42.685872
# Gard                     25.250000     31.375000   4.357343  43.832422
# Seine-et-Marne           23.555556     28.648148   2.596910  48.702632
# Eure                     19.000000     30.291667   1.142002  49.025866
# Vendée                   20.000000     23.750000  -1.430032  46.670255
# Hauts-de-Seine           23.916667     24.527778   2.276798  48.813229
# Hérault                  19.966250     22.669583   3.850566  43.615726
# Bouches-du-Rhône         19.573913     23.716370   5.420482  43.408135
# Yvelines                 25.502500     25.502500   2.078641  48.789272
# Mayenne                  18.740000     22.347500  -0.759058  48.080550
# Var                      16.625000     21.093750   5.996027  43.131964
# Ardennes                 19.500000     19.500000   4.783700  49.748650
# Moselle                  29.800000     34.933333   6.371323  49.160202
# Essonne                  19.666667     19.666667   2.253187  48.678907
# Seine-Maritime           17.625000     20.241898   0.722594  49.460099
# Puy-de-Dôme              17.666667     23.520000   3.100777  45.770145
# Somme                    18.686364     22.836970   2.289495  49.893811
# Métropole de Lyon        18.000000     48.083333   4.852303  45.756218
# Vosges                   11.500000     13.500000   6.459698  48.187951
# Seine-Saint-Denis        18.230769     24.967949   2.390101  48.927118
# Guadeloupe               16.111111     16.333333 -61.587007  16.161524
# Doubs                    16.666667     24.860069   6.273136  47.327416
# Haute-Corse              16.000000     16.000000   9.153932  42.301827
# Territoire-de-Belfort    15.333333     25.922222   6.848108  47.641122
# Loire-Atlantique         15.434783     19.940652  -1.616177  47.239854
# Isère                    12.000000     12.000000   5.744375  45.187858
# Maine-et-Loire           15.649286     24.551429  -0.569444  47.474853
# Savoie                   16.000000     29.111111   5.897526  45.599188
# Calvados                 16.000000     25.210417  -0.352579  49.203838
# Oise                     15.800000     23.188600   2.596554  49.378709
# Val-de-Marne             18.600000     22.540000   2.416944  48.793465
# Sarthe                   15.000000     19.750000   0.160106  48.017279
# Meurthe-et-Moselle       12.571429     16.755952   6.142818  48.735877
# Alpes-Maritimes          16.714286     23.220238   7.192539  43.671555
# Allier                   10.000000     15.333333   2.588071  46.329269
# Bas-Rhin                 16.083333     18.458333   7.765154  48.573450
# Paris                    17.780000     22.712817   2.357457  48.860827
# Haut-Rhin                15.250000     17.125000   7.313592  47.731501
# Marne                    12.428571     14.321429   4.065565  49.213082
# Aube                     12.000000     12.000000   4.077813  48.279540
#
#                         upr.IPm2  Nbstudents_total  prix_par_m2_min  \
# departement
# Vaucluse               14.315362       6787.000000        11.476546
# Aisne                  11.992983          0.000000        12.683688
# Pyrénées-Orientales    12.694461       8569.000000        12.685152
# Gard                   13.606911       5459.000000        13.134632
# Seine-et-Marne         19.202476       8821.555556        13.803151
# Eure                   13.446488          0.000000        13.920556
# Vendée                 12.042086          0.000000        15.483000
# Hauts-de-Seine         27.170879     255988.916667        15.517091
# Hérault                16.910738      67388.148148        15.586181
# Bouches-du-Rhône       19.061653      36696.750000        15.656064
# Yvelines               23.439544      51367.285714        15.957204
# Mayenne                11.700714          0.000000        16.513749
# Var                    16.612814      10652.000000        16.670387
# Ardennes               11.424043          0.000000        16.820833
# Moselle                13.969350          0.000000        17.454059
# Essonne                20.592451      35942.692308        17.595008
# Seine-Maritime         14.424602      25534.375000        17.902797
# Puy-de-Dôme            13.777523      36266.000000        18.090464
# Somme                  14.873270      32266.000000        18.142982
# Métropole de Lyon      18.146949     110640.125000        18.250000
# Vosges                 10.888784          0.000000        18.498252
# Seine-Saint-Denis      23.077902     246717.692308        18.706134
# Guadeloupe             20.418301       8418.666667        19.332012
# Doubs                  13.376912      18503.000000        19.355823
# Haute-Corse            17.229563          0.000000        19.466667
# Territoire-de-Belfort  13.046841       2641.000000        19.637427
# Loire-Atlantique       15.162260      40533.652174        20.097009
# Isère                  15.766870      57964.000000        20.416667
# Maine-et-Loire         13.494467      25814.000000        20.526717
# Savoie                 15.823069      14037.000000        20.591503
# Calvados               14.104899      32933.000000        20.765224
# Oise                   15.553194       2615.400000        20.791152
# Val-de-Marne           24.112427     232723.333333        21.103154
# Sarthe                 12.283727      11169.000000        21.321111
# Meurthe-et-Moselle     13.464398      60613.466667        21.587759
# Alpes-Maritimes        23.047354      24593.800000        21.604926
# Allier                 10.386274          0.000000        22.020000
# Bas-Rhin               16.519697      47886.384615        22.210439
# Paris                  37.095264     286373.170732        23.120340
# Haut-Rhin              14.420898      10029.000000        23.312500
# Marne                  14.258582      23701.333333        24.615873
# Aube                   13.147722       3235.000000        26.583333
#
#                                  departement
# departement
# Vaucluse                            Vaucluse
# Aisne                                  Aisne
# Pyrénées-Orientales      Pyrénées-Orientales
# Gard                                    Gard
# Seine-et-Marne                Seine-et-Marne
# Eure                                    Eure
# Vendée                                Vendée
# Hauts-de-Seine                Hauts-de-Seine
# Hérault                              Hérault
# Bouches-du-Rhône            Bouches-du-Rhône
# Yvelines                            Yvelines
# Mayenne                              Mayenne
# Var                                      Var
# Ardennes                            Ardennes
# Moselle                              Moselle
# Essonne                              Essonne
# Seine-Maritime                Seine-Maritime
# Puy-de-Dôme                      Puy-de-Dôme
# Somme                                  Somme
# Métropole de Lyon          Métropole de Lyon
# Vosges                                Vosges
# Seine-Saint-Denis          Seine-Saint-Denis
# Guadeloupe                        Guadeloupe
# Doubs                                  Doubs
# Haute-Corse                      Haute-Corse
# Territoire-de-Belfort  Territoire-de-Belfort
# Loire-Atlantique            Loire-Atlantique
# Isère                                  Isère
# Maine-et-Loire                Maine-et-Loire
# Savoie                                Savoie
# Calvados                            Calvados
# Oise                                    Oise
# Val-de-Marne                    Val-de-Marne
# Sarthe                                Sarthe
# Meurthe-et-Moselle        Meurthe-et-Moselle
# Alpes-Maritimes              Alpes-Maritimes
# Allier                                Allier
# Bas-Rhin                            Bas-Rhin
# Paris                                  Paris
# Haut-Rhin                          Haut-Rhin
# Marne                                  Marne
# Aube                                    Aube

# %%
departments = df3['departement']
prix_m2 = df3['prix_par_m2_min']
plt.bar(departments,prix_m2)
plt.xticks(departments, rotation = 'vertical', size =8)
plt.xlabel('Départment')
plt.ylabel('Prix au m2 studio Crous par département')
plt.show()

# %% [markdown]
# ## Ajout de la colonne 'prix_par_m2_max'(qui correspond le plus souvent à des logements en colocation (T2/T3/T4))

# %%
df['prix_par_m2_max'] = df['Max Loyer']/df['Max Surface'] # On crée une nouvelle variable prix_par_m2_min

# %%
df.groupby(['departement']).mean().sort_values('prix_par_m2_max')
# Out:
# /tmp/ipykernel_194/2332010617.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['departement']).mean().sort_values('prix_par_m2_max')
#                       Max Loyer   Min Loyer  Mean Loyer  Max Surface  \
# departement
# Métropole de Lyon    384.258065  291.193548  334.958871        91.00
# Eure                 385.400000  265.800000  318.800000        45.00
# Vendée               329.635000  324.185000  326.910000        28.00
# Gard                 413.138333  325.600000  365.063611        40.50
# Pyrénées-Orientales  377.166667  313.833333  346.083333        34.00
# ...                         ...         ...         ...          ...
# Saône-et-Loire              NaN         NaN         NaN          NaN
# Tarn                        NaN         NaN         NaN        23.75
# Val-d'Oise           364.700000  288.857143  326.778571          NaN
# Vienne                      NaN         NaN         NaN          NaN
# Yonne                       NaN         NaN         NaN          NaN
#
#                      Min Surface  Mean Surface  Longitude   Latitude  \
# departement
# Métropole de Lyon          18.00     48.083333   4.852303  45.756218
# Eure                       19.00     30.291667   1.142002  49.025866
# Vendée                     20.00     23.750000  -1.430032  46.670255
# Gard                       25.25     31.375000   4.357343  43.832422
# Pyrénées-Orientales        26.20     30.100000   2.895255  42.685872
# ...                          ...           ...        ...        ...
# Saône-et-Loire               NaN           NaN   4.428220  46.806198
# Tarn                       21.25     22.500000   2.168522  43.842574
# Val-d'Oise                   NaN           NaN   2.065076  49.036170
# Vienne                       NaN           NaN   0.362823  46.590238
# Yonne                        NaN           NaN   3.570971  47.798664
#
#                       upr.IPm2  Nbstudents_total  prix_par_m2_min  \
# departement
# Métropole de Lyon    18.146949     110640.125000        18.250000
# Eure                 13.446488          0.000000        13.920556
# Vendée               12.042086          0.000000        15.483000
# Gard                 13.606911       5459.000000        13.134632
# Pyrénées-Orientales  12.694461       8569.000000        12.685152
# ...                        ...               ...              ...
# Saône-et-Loire       10.567857          0.000000              NaN
# Tarn                 11.575138       2806.500000              NaN
# Val-d'Oise           20.620895      26943.000000              NaN
# Vienne               12.455215      26072.153846              NaN
# Yonne                12.289543          0.000000              NaN
#
#                      prix_par_m2_max
# departement
# Métropole de Lyon           4.496288
# Eure                        8.940779
# Vendée                     11.448571
# Gard                       11.927731
# Pyrénées-Orientales        11.930502
# ...                              ...
# Saône-et-Loire                   NaN
# Tarn                             NaN
# Val-d'Oise                       NaN
# Vienne                           NaN
# Yonne                            NaN
#
# [82 rows x 12 columns]

# %%
df_max = df.groupby(['departement']).mean().sort_values('prix_par_m2_max')
df_max = df_max.loc[(df_max['prix_par_m2_max']>1)]
# Out:
# /tmp/ipykernel_194/1211382413.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_max = df.groupby(['departement']).mean().sort_values('prix_par_m2_max')

# %%
df_max['departement'] = df_max.index #je crée une colonne qui correspond à l'index (la colonne regions)
df_max
# Out:
#                         Max Loyer   Min Loyer  Mean Loyer  Max Surface  \
# departement
# Métropole de Lyon      384.258065  291.193548  334.958871    91.000000
# Eure                   385.400000  265.800000  318.800000    45.000000
# Vendée                 329.635000  324.185000  326.910000    28.000000
# Gard                   413.138333  325.600000  365.063611    40.500000
# Pyrénées-Orientales    377.166667  313.833333  346.083333    34.000000
# Seine-et-Marne         405.333333  318.333333  360.314815    34.000000
# Vaucluse               393.535714  246.552857  308.777857    30.087143
# Mayenne                353.160000  308.855000  331.007500    25.955000
# Doubs                  439.333333  302.500000  371.616162    35.966667
# Moselle                435.494000  319.028000  374.024100    42.300000
# Maine-et-Loire         363.537143  299.158571  325.516190    39.245000
# Sarthe                 352.775000  284.410000  318.592500    24.500000
# Seine-Saint-Denis      441.153846  334.692308  383.554487    31.923077
# Aisne                  307.750000  261.670000  284.710000    20.700000
# Savoie                 393.800000  298.200000  345.266667    42.200000
# Puy-de-Dôme            349.625000  290.718750  319.438542    29.933333
# Calvados               428.268750  295.360000  362.774167    35.000000
# Vosges                 229.750000  211.250000  221.000000    15.500000
# Alpes-Maritimes        446.690000  333.090000  387.366944    31.071429
# Bouches-du-Rhône       410.341852  252.498889  326.068976    28.186957
# Territoire-de-Belfort  424.000000  272.000000  339.523810    36.100000
# Allier                 300.000000  220.200000  260.200000    18.000000
# Seine-Maritime         365.900000  298.425000  331.336250    24.208333
# Val-de-Marne           442.600000  353.800000  399.214286    27.000000
# Hérault                401.296296  299.555556  347.553386    25.216250
# Loire-Atlantique       379.009130  290.576087  332.549862    25.782609
# Ardennes               342.000000  326.750000  334.375000    19.500000
# Guadeloupe             303.666667  296.333333  300.000000    16.555556
# Somme                  434.973846  305.005385  374.084222    27.420909
# Var                    456.825000  262.775000  357.790625    26.250000
# Oise                   399.420000  313.754000  362.683533    37.730000
# Paris                  525.153846  394.756410  452.706593    29.406667
# Haute-Corse            358.250000  358.250000  358.250000    16.000000
# Essonne                376.750000  280.916667  328.833333    19.666667
# Meurthe-et-Moselle     397.027143  267.762857  336.526071    21.071429
# Bas-Rhin               415.000000  329.000000  373.090909    20.666667
# Yvelines               536.000000  374.714286  455.357143    25.502500
# Hauts-de-Seine         464.427273  327.236364  394.922727    25.416667
# Haut-Rhin              376.250000  342.250000  359.250000    19.000000
# Marne                  366.666667  278.333333  322.611111    16.000000
# Aube                   339.000000  305.666667  324.833333    12.000000
# Isère                  388.083333  267.500000  323.847222    12.000000
#
#                        Min Surface  Mean Surface  Longitude   Latitude  \
# departement
# Métropole de Lyon        18.000000     48.083333   4.852303  45.756218
# Eure                     19.000000     30.291667   1.142002  49.025866
# Vendée                   20.000000     23.750000  -1.430032  46.670255
# Gard                     25.250000     31.375000   4.357343  43.832422
# Pyrénées-Orientales      26.200000     30.100000   2.895255  42.685872
# Seine-et-Marne           23.555556     28.648148   2.596910  48.702632
# Vaucluse                 23.815714     26.951429   4.828818  43.944533
# Mayenne                  18.740000     22.347500  -0.759058  48.080550
# Doubs                    16.666667     24.860069   6.273136  47.327416
# Moselle                  29.800000     34.933333   6.371323  49.160202
# Maine-et-Loire           15.649286     24.551429  -0.569444  47.474853
# Sarthe                   15.000000     19.750000   0.160106  48.017279
# Seine-Saint-Denis        18.230769     24.967949   2.390101  48.927118
# Aisne                    20.700000     20.700000   3.302897  49.841917
# Savoie                   16.000000     29.111111   5.897526  45.599188
# Puy-de-Dôme              17.666667     23.520000   3.100777  45.770145
# Calvados                 16.000000     25.210417  -0.352579  49.203838
# Vosges                   11.500000     13.500000   6.459698  48.187951
# Alpes-Maritimes          16.714286     23.220238   7.192539  43.671555
# Bouches-du-Rhône         19.573913     23.716370   5.420482  43.408135
# Territoire-de-Belfort    15.333333     25.922222   6.848108  47.641122
# Allier                   10.000000     15.333333   2.588071  46.329269
# Seine-Maritime           17.625000     20.241898   0.722594  49.460099
# Val-de-Marne             18.600000     22.540000   2.416944  48.793465
# Hérault                  19.966250     22.669583   3.850566  43.615726
# Loire-Atlantique         15.434783     19.940652  -1.616177  47.239854
# Ardennes                 19.500000     19.500000   4.783700  49.748650
# Guadeloupe               16.111111     16.333333 -61.587007  16.161524
# Somme                    18.686364     22.836970   2.289495  49.893811
# Var                      16.625000     21.093750   5.996027  43.131964
# Oise                     15.800000     23.188600   2.596554  49.378709
# Paris                    17.780000     22.712817   2.357457  48.860827
# Haute-Corse              16.000000     16.000000   9.153932  42.301827
# Essonne                  19.666667     19.666667   2.253187  48.678907
# Meurthe-et-Moselle       12.571429     16.755952   6.142818  48.735877
# Bas-Rhin                 16.083333     18.458333   7.765154  48.573450
# Yvelines                 25.502500     25.502500   2.078641  48.789272
# Hauts-de-Seine           23.916667     24.527778   2.276798  48.813229
# Haut-Rhin                15.250000     17.125000   7.313592  47.731501
# Marne                    12.428571     14.321429   4.065565  49.213082
# Aube                     12.000000     12.000000   4.077813  48.279540
# Isère                    12.000000     12.000000   5.744375  45.187858
#
#                         upr.IPm2  Nbstudents_total  prix_par_m2_min  \
# departement
# Métropole de Lyon      18.146949     110640.125000        18.250000
# Eure                   13.446488          0.000000        13.920556
# Vendée                 12.042086          0.000000        15.483000
# Gard                   13.606911       5459.000000        13.134632
# Pyrénées-Orientales    12.694461       8569.000000        12.685152
# Seine-et-Marne         19.202476       8821.555556        13.803151
# Vaucluse               14.315362       6787.000000        11.476546
# Mayenne                11.700714          0.000000        16.513749
# Doubs                  13.376912      18503.000000        19.355823
# Moselle                13.969350          0.000000        17.454059
# Maine-et-Loire         13.494467      25814.000000        20.526717
# Sarthe                 12.283727      11169.000000        21.321111
# Seine-Saint-Denis      23.077902     246717.692308        18.706134
# Aisne                  11.992983          0.000000        12.683688
# Savoie                 15.823069      14037.000000        20.591503
# Puy-de-Dôme            13.777523      36266.000000        18.090464
# Calvados               14.104899      32933.000000        20.765224
# Vosges                 10.888784          0.000000        18.498252
# Alpes-Maritimes        23.047354      24593.800000        21.604926
# Bouches-du-Rhône       19.061653      36696.750000        15.656064
# Territoire-de-Belfort  13.046841       2641.000000        19.637427
# Allier                 10.386274          0.000000        22.020000
# Seine-Maritime         14.424602      25534.375000        17.902797
# Val-de-Marne           24.112427     232723.333333        21.103154
# Hérault                16.910738      67388.148148        15.586181
# Loire-Atlantique       15.162260      40533.652174        20.097009
# Ardennes               11.424043          0.000000        16.820833
# Guadeloupe             20.418301       8418.666667        19.332012
# Somme                  14.873270      32266.000000        18.142982
# Var                    16.612814      10652.000000        16.670387
# Oise                   15.553194       2615.400000        20.791152
# Paris                  37.095264     286373.170732        23.120340
# Haute-Corse            17.229563          0.000000        19.466667
# Essonne                20.592451      35942.692308        17.595008
# Meurthe-et-Moselle     13.464398      60613.466667        21.587759
# Bas-Rhin               16.519697      47886.384615        22.210439
# Yvelines               23.439544      51367.285714        15.957204
# Hauts-de-Seine         27.170879     255988.916667        15.517091
# Haut-Rhin              14.420898      10029.000000        23.312500
# Marne                  14.258582      23701.333333        24.615873
# Aube                   13.147722       3235.000000        26.583333
# Isère                  15.766870      57964.000000        20.416667
#
#                        prix_par_m2_max            departement
# departement
# Métropole de Lyon             4.496288      Métropole de Lyon
# Eure                          8.940779                   Eure
# Vendée                       11.448571                 Vendée
# Gard                         11.927731                   Gard
# Pyrénées-Orientales          11.930502    Pyrénées-Orientales
# Seine-et-Marne               13.061726         Seine-et-Marne
# Vaucluse                     13.885956               Vaucluse
# Mayenne                      14.106336                Mayenne
# Doubs                        14.115484                  Doubs
# Moselle                      14.220118                Moselle
# Maine-et-Loire               14.422716         Maine-et-Loire
# Sarthe                       14.757975                 Sarthe
# Seine-Saint-Denis            14.885239      Seine-Saint-Denis
# Aisne                        14.917281                  Aisne
# Savoie                       15.120748                 Savoie
# Puy-de-Dôme                  15.587618            Puy-de-Dôme
# Calvados                     15.600343               Calvados
# Vosges                       15.667553                 Vosges
# Alpes-Maritimes              16.054352        Alpes-Maritimes
# Bouches-du-Rhône             16.276347       Bouches-du-Rhône
# Territoire-de-Belfort        16.363158  Territoire-de-Belfort
# Allier                       16.666667                 Allier
# Seine-Maritime               16.901872         Seine-Maritime
# Val-de-Marne                 16.926334           Val-de-Marne
# Hérault                      17.073900                Hérault
# Loire-Atlantique             17.273318       Loire-Atlantique
# Ardennes                     17.583333               Ardennes
# Guadeloupe                   17.603506             Guadeloupe
# Somme                        18.690451                  Somme
# Var                          18.826259                    Var
# Oise                         18.989025                   Oise
# Paris                        19.368879                  Paris
# Haute-Corse                  19.466667            Haute-Corse
# Essonne                      19.696457                Essonne
# Meurthe-et-Moselle           19.856414     Meurthe-et-Moselle
# Bas-Rhin                     20.167192               Bas-Rhin
# Yvelines                     21.078482               Yvelines
# Hauts-de-Seine               21.351357         Hauts-de-Seine
# Haut-Rhin                    22.291035              Haut-Rhin
# Marne                        24.664423                  Marne
# Aube                         26.583333                   Aube
# Isère                        28.625000                  Isère

# %%
departments = df_max['departement']
prix_m2_max = df_max['prix_par_m2_max']
plt.bar(departments,prix_m2_max)
plt.xticks(departments, rotation = 'vertical', size =8)
plt.xlabel('Départment')
plt.ylabel('Prix au m2 colocation Crous par département')
plt.show()

# %% [markdown]
# ## Ajout de la colonne 'prix_par_m2_mean'(qui correspond à la moyenne des loyers des logements porposés)

# %%
df['prix_par_m2_mean'] = df['Mean Loyer']/df['Mean Surface'] # On crée une nouvelle variable prix_par_m2_mean
df

df_mean = df.groupby(['departement']).mean().sort_values('prix_par_m2_mean')
df_mean = df_mean.loc[(df_mean['prix_par_m2_mean']>1)] 
df_mean['departement'] = df_mean.index
# Out:
# /tmp/ipykernel_194/1503173995.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_mean = df.groupby(['departement']).mean().sort_values('prix_par_m2_mean')

# %%
departments = df_mean['departement']
prix_m2_mean = df_mean['prix_par_m2_mean']
plt.bar(departments,prix_m2_mean)
plt.xticks(departments, rotation = 'vertical', size =8)
plt.xlabel('Départment')
plt.ylabel('Prix au m2 moyen Crous par département')
plt.show()

# %% [markdown]
# ## Construction de graphes pour surfaces min et max

# %%
df_surface_min = df.groupby(['departement']).mean().sort_values('Min Surface')
df_surface_min
# Out:
# /tmp/ipykernel_194/2751980484.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_surface_min = df.groupby(['departement']).mean().sort_values('Min Surface')
#                  Max Loyer   Min Loyer  Mean Loyer  Max Surface  Min Surface  \
# departement
# Morbihan               NaN         NaN         NaN          9.0          9.0
# Allier          300.000000  220.200000  260.200000         18.0         10.0
# Vosges          229.750000  211.250000  221.000000         15.5         11.5
# Aube            339.000000  305.666667  324.833333         12.0         12.0
# Isère           388.083333  267.500000  323.847222         12.0         12.0
# ...                    ...         ...         ...          ...          ...
# Pas-de-Calais          NaN         NaN         NaN          NaN          NaN
# Saône-et-Loire         NaN         NaN         NaN          NaN          NaN
# Val-d'Oise      364.700000  288.857143  326.778571          NaN          NaN
# Vienne                 NaN         NaN         NaN          NaN          NaN
# Yonne                  NaN         NaN         NaN          NaN          NaN
#
#                 Mean Surface  Longitude   Latitude   upr.IPm2  \
# departement
# Morbihan            9.000000  -3.081417  47.693140  12.314890
# Allier             15.333333   2.588071  46.329269  10.386274
# Vosges             13.500000   6.459698  48.187951  10.888784
# Aube               12.000000   4.077813  48.279540  13.147722
# Isère              12.000000   5.744375  45.187858  15.766870
# ...                      ...        ...        ...        ...
# Pas-de-Calais            NaN   2.302964  50.545309  12.709430
# Saône-et-Loire           NaN   4.428220  46.806198  10.567857
# Val-d'Oise               NaN   2.065076  49.036170  20.620895
# Vienne                   NaN   0.362823  46.590238  12.455215
# Yonne                    NaN   3.570971  47.798664  12.289543
#
#                 Nbstudents_total  prix_par_m2_min  prix_par_m2_max  \
# departement
# Morbihan             5406.000000              NaN              NaN
# Allier                  0.000000        22.020000        16.666667
# Vosges                  0.000000        18.498252        15.667553
# Aube                 3235.000000        26.583333        26.583333
# Isère               57964.000000        20.416667        28.625000
# ...                          ...              ...              ...
# Pas-de-Calais        4506.461538              NaN              NaN
# Saône-et-Loire          0.000000              NaN              NaN
# Val-d'Oise          26943.000000              NaN              NaN
# Vienne              26072.153846              NaN              NaN
# Yonne                   0.000000              NaN              NaN
#
#                 prix_par_m2_mean
# departement
# Morbihan                     NaN
# Allier                 16.969565
# Vosges                 16.677636
# Aube                   26.583333
# Isère                  24.388889
# ...                          ...
# Pas-de-Calais                NaN
# Saône-et-Loire               NaN
# Val-d'Oise                   NaN
# Vienne                       NaN
# Yonne                        NaN
#
# [82 rows x 13 columns]

# %%
df_surface_min = df_surface_min.groupby(['departement']).mean().sort_values('Min Surface')
df_surface_min 
df_surface_min = df_surface_min.loc[(df_surface_min['Min Surface']>1)] 
df_surface_min['departement'] = df_surface_min.index

# %%
departments = df_surface_min['departement']
Min_Surface = df_surface_min['Min Surface']
plt.bar(departments,Min_Surface)
plt.xticks(departments, rotation = 'vertical', size =7)
plt.xlabel('Départment')
plt.ylabel('Surface minimale studio Crous par département')
plt.show()

# %%
df_surface_max = df.groupby(['departement']).mean().sort_values('Max Surface')
df_surface_max 
df_surface_max = df_surface_max.loc[(df_surface_max['Max Surface']>1)] 
df_surface_max['departement'] = df_surface_max.index
# Out:
# /tmp/ipykernel_194/972686478.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_surface_max = df.groupby(['departement']).mean().sort_values('Max Surface')

# %%
df_surface_max = df.groupby(['departement']).mean().sort_values('Max Surface')
df_surface_max
# Out:
# /tmp/ipykernel_194/2977350110.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_surface_max = df.groupby(['departement']).mean().sort_values('Max Surface')
#                   Max Loyer   Min Loyer  Mean Loyer  Max Surface  Min Surface  \
# departement
# Morbihan                NaN         NaN         NaN     9.000000     9.000000
# Aube             339.000000  305.666667  324.833333    12.000000    12.000000
# Isère            388.083333  267.500000  323.847222    12.000000    12.000000
# Martinique              NaN         NaN         NaN    12.333333    12.333333
# Hautes-Pyrénées         NaN         NaN         NaN    14.000000    14.000000
# ...                     ...         ...         ...          ...          ...
# Pas-de-Calais           NaN         NaN         NaN          NaN          NaN
# Saône-et-Loire          NaN         NaN         NaN          NaN          NaN
# Val-d'Oise       364.700000  288.857143  326.778571          NaN          NaN
# Vienne                  NaN         NaN         NaN          NaN          NaN
# Yonne                   NaN         NaN         NaN          NaN          NaN
#
#                  Mean Surface  Longitude   Latitude   upr.IPm2  \
# departement
# Morbihan             9.000000  -3.081417  47.693140  12.314890
# Aube                12.000000   4.077813  48.279540  13.147722
# Isère               12.000000   5.744375  45.187858  15.766870
# Martinique          12.333333 -61.090497  14.617867  19.734606
# Hautes-Pyrénées     14.000000   0.049889  43.227901  11.431427
# ...                       ...        ...        ...        ...
# Pas-de-Calais             NaN   2.302964  50.545309  12.709430
# Saône-et-Loire            NaN   4.428220  46.806198  10.567857
# Val-d'Oise                NaN   2.065076  49.036170  20.620895
# Vienne                    NaN   0.362823  46.590238  12.455215
# Yonne                     NaN   3.570971  47.798664  12.289543
#
#                  Nbstudents_total  prix_par_m2_min  prix_par_m2_max  \
# departement
# Morbihan              5406.000000              NaN              NaN
# Aube                  3235.000000        26.583333        26.583333
# Isère                57964.000000        20.416667        28.625000
# Martinique               0.000000              NaN              NaN
# Hautes-Pyrénées       1194.000000              NaN              NaN
# ...                           ...              ...              ...
# Pas-de-Calais         4506.461538              NaN              NaN
# Saône-et-Loire           0.000000              NaN              NaN
# Val-d'Oise           26943.000000              NaN              NaN
# Vienne               26072.153846              NaN              NaN
# Yonne                    0.000000              NaN              NaN
#
#                  prix_par_m2_mean
# departement
# Morbihan                      NaN
# Aube                    26.583333
# Isère                   24.388889
# Martinique                    NaN
# Hautes-Pyrénées               NaN
# ...                           ...
# Pas-de-Calais                 NaN
# Saône-et-Loire                NaN
# Val-d'Oise                    NaN
# Vienne                        NaN
# Yonne                         NaN
#
# [82 rows x 13 columns]

# %%
departments = df_surface_max['departement']
Max_Surface = df_surface_max['Max Surface']
plt.bar(departments,Max_Surface)
plt.xticks(departments, rotation = 'vertical', size =7)
plt.xlabel('Départment')
plt.ylabel('Surface maximale colocation Crous par département')
plt.show()

# %% [markdown]
# ## Compter le nombre de residence Crous par région

# %%
df['comptage_résidence']= 1
df.head(5)
df_nb_res = df.groupby(['departement']).sum().sort_values('comptage_résidence', ascending = False)

df_nb_res['departement'] = df_nb_res.index #je crée une colonne qui correspond à l'index (la colonne regions)

df_nb_res

df_nb_res_moins = df_nb_res.loc[(df_nb_res['comptage_résidence']<5)] 
#sns.barplot(y='departement', x='comptage_résidence', data= df_nb_res, width= 0.2, orient="h").set_title('Nombre de résidence par départements')#OK
# Out:
# /tmp/ipykernel_194/386916076.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_nb_res = df.groupby(['departement']).sum().sort_values('comptage_résidence', ascending = False)

# %%
departments = df_nb_res_moins['departement']
Nb_résidence = df_nb_res_moins['comptage_résidence']
plt.bar(departments,Nb_résidence )
plt.xticks(departments, rotation = 'vertical', size =7)
plt.xlabel('Départments')
plt.ylabel('Départements avec moins de 5 résidences Crous')
plt.show()

# %%
df_nb_res_plus = df_nb_res.loc[(df_nb_res['comptage_résidence']>20)] 
departments = df_nb_res_plus['departement']
Nb_résidence = df_nb_res_plus['comptage_résidence']
plt.bar(departments,Nb_résidence )
plt.xticks(departments, rotation = 'vertical', size =7)
plt.xlabel('Départments')
plt.ylabel('Départements avec le plus de résidences résidences Crous (>20)')
plt.show()

# %% [markdown]
# ## 2.2 La France des Crous
#
# On retire les territoires et régions d'Outre-Mer pour réaliser des carte

# %%
df_metro = df[ (df["regions"] != "La Réunion") &

                    (df["regions"] != "Guadeloupe") &

                    (df["regions"] != "Martinique") &

                    (df["regions"] != "Guyane")]

df_metro.reset_index(inplace = True)

# %% [markdown]
# ### 2.2.1 Classical maps

# %%
"""
On récupère un fond de carte de la France.
"""

France = gpd.read_file("https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/france.geojson")

# %%
fig, ax = plt.subplots(figsize=(24, 18))
France.plot(ax =ax, edgecolor='darkgrey', facecolor='lightgrey')

df_metro.plot(ax = ax, color='red')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### 2.2.2. Interactive maps

# %%
map = folium.Map(location=[48.7144587, 2.2453842], tiles="OpenStreetMap", zoom_start=11)

# Create a geometry list from the GeoDataFrame

geo_df_list = [[point.xy[1][0], point.xy[0][0]] for point in df_metro.geometry] 


# Iterate through list and add a marker for each residence, color-coded by its type.

i = 0

for coordinates in geo_df_list:

    # Place the markers with the popup labels and data

    map.add_child(

        folium.Marker(

            location=coordinates,

            popup=

                 "Name: " + str(df_metro.title[i]) + "<br>"

                + "Moyenne Loyer: " + str(df_metro["Mean Loyer"][i]) + "<br>"

                + "Moyenne surface: " + str(df_metro["Mean Surface"][i]) + "<br>"

                + "Address: " + str(df_metro.address[i]) + "<br>"

                + "Coordinates: " + str(geo_df_list[i])

            ,

        

            icon=folium.Icon(color="blue"),

        )

    )

    i = i + 1

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e37c00b0f4f9c26d1a57a3daa3d190c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e37c00b0f4f9c26d1a57a3daa3d190c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e37c00b0f4f9c26d1a57a3daa3d190c = L.map(
#                 &quot;map_4e37c00b0f4f9c26d1a57a3daa3d190c&quot;,
#                 {
#                     center: [48.7144587, 2.2453842],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_700b1d41b8aa1f45776469e94cc3ad9d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4e37c00b0f4f9c26d1a57a3daa3d190c);
#
#
#             var marker_95c1a624892cd073a11e80ba0f548496 = L.marker(
#                 [48.7796516418, 2.0441513062],
#                 {}
#             ).addTo(map_4e37c00b0f4f9c26d1a57a3daa3d190c);
#
#
#             var icon_2fede3cf8837887761f8305d8e4d716e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_95c1a624892cd073a11e80ba0f548496.setIcon(icon_2fede3cf8837887761f8305d8e4d716e);
#
#
#         var popup_0805394c10d13835c4a4d5359f122317 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db32ddf3efa7741657f0b95d8ff5b9e3 = $(`&lt;div id=&quot;html_db32ddf3efa7741657f0b95d8ff5b9e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Résidence Vauban&lt;br&gt;Moyenne Loyer: 435.0&lt;br&gt;Moyenne surface: nan&lt;br&gt;Address: 1 boulevard d’Alembert 78280 Guyancourt&lt;br&gt;Coordinates: [48.7796516418, 2.0441513062]&lt;/div&gt;`)[0];
#                 popup_0805394c10d13835c4a4d5359f122317.setContent(html_db32ddf3efa7741657f0b95d8ff5b9e3);
#
#
#
#         marker_95c1a624892cd073a11e80ba0f548496.bindPopup(popup_0805394c10d13835c4a4d5359f122317)
#         ;
#
#
#
#
#             var marker_2e74406308605c064e9d2515eb8199d8 = L.marker(
#                 [49.0482978821, 2.02688694],
#                 {}
#             ).addTo(map_4e37c00b0f4f9c26d1a57a3daa3d190c);
#
#
#             var icon_f150901f245dd0dcdc6f1fcbb244f8a0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2e74406308605c064e9d2515eb8199d8.setIcon(icon_f150901f245dd0dcdc6f1fcbb244f8a0);
#
#
#         var popup_490439ab89fcedc1b7b15dbe9a142c2c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f29038851a1637465be2afd4ceecd0cd = $(`&lt;div id=&quot;html_f29038851a1637465be2afd4ceecd0cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Résidence Le Square de l&#x27;Echiquier&lt;br&gt;Moyenne Loyer: 334.0&lt;br&gt;Moyenne surface: nan&lt;br&gt;Address: 9 square de l&#x27;échiquier 95800 Cergy-Pontoise&lt;br&gt;Coordinates: [49.0482978821, 2.02688694]&lt;/div&gt;`)[0];
#                 popup_490439ab89fcedc1b7b15dbe9a142c2c.setContent(html_f29038851a1637465be2afd4ceecd0cd);
#
#
#
#         marker_2e74406308605c064e9d2515eb8199d8.bindPopup(popup_490439ab89fcedc1b7b15dbe9a142c2c)
#         ;
#
#
#
#
#             var marker_ebf27c644a4efa46b6a55376a903cc13 = L.marker(
#                 [48.7906913757, 2.3169708252],
#                 {}
#             ).addTo(map_4e37c00b0f4f9c26d1a57a3daa3d190c);
#
#
#             var icon_63228a7a458d71b07d1a4f35b1423fa1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ebf27c644a4efa46b6a55376a903cc13.setIcon(icon_63228a7a458d71b07d1a4f35b1423fa1);
#
#
#         var popup_729ab4853fd6fb2db44cdd5d8e76675b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_292fccdc9f64649a2bb9f2f8866cd54c = $(`&lt;div id=&quot;html_292fccdc9f64649a2bb9f2f8866cd54c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Résidence Les Bas Longchamps&lt;br&gt;Moyenne Loyer: 345.5&lt;br&gt;Moyenne surface: 28.0&lt;br&gt;Address: 2 rue Abraham Lincoln 92220 Bagneux&lt;br&gt;Coordinates: [48.7906913757, 2.3169708252]&lt;/div&gt;`)[0];
#                 popup_729ab4853fd6fb2db44cdd5d8e76675b.setContent(html_292fccdc9f64649a2bb9f2f8866cd54c);
#
#
#
#         marker_ebf27c644a4

# %% [markdown]
# ### 2.2.3 cartes statistiques

# %%
gdf_mean = df_metro.groupby(['departement']).mean().sort_values('prix_par_m2_mean')
gdf_mean['departement'] = gdf_mean.index
# Out:
# /tmp/ipykernel_1182/615003632.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gdf_mean = df_metro.groupby(['departement']).mean().sort_values('prix_par_m2_mean')

# %%
gpd_mean = gpd.GeoDataFrame(gdf_mean.set_index('departement').join(gdf_dep.set_index('departement')))

# %%
gpd_mean_wout_nan = gpd_mean[gpd_mean['prix_par_m2_mean'] > 1]

# %%
fig, ax = plt.subplots(figsize=(24, 18))
France.plot(ax =ax, edgecolor='darkgrey', facecolor='lightgrey')

# Set up the color sheme:
import mapclassify as mc
scheme = mc.Quantiles(gpd_mean_wout_nan['prix_par_m2_mean'], k=10)

# Map
gplt.choropleth(gpd_mean_wout_nan, 
    hue="prix_par_m2_mean", 
    linewidth=.1,
    scheme=scheme, cmap='inferno_r',
    legend=True,
    edgecolor='black',
    ax=ax
                
);

ax.set_title('Mean crous rent in french departements', fontsize=13);
# Out:
# /opt/mamba/lib/python3.10/site-packages/geoplot/geoplot.py:982: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for subgeom in geom:

# %%
fig, ax = plt.subplots(figsize=(24, 18))
France.plot(ax =ax, edgecolor='darkgrey', facecolor='lightgrey')

# Set up the color sheme:
import mapclassify as mc
scheme = mc.Quantiles(gpd_mean_wout_nan['prix_par_m2_mean'], k=10)

# Map
gplt.choropleth(gpd_mean_wout_nan, 
    hue="prix_par_m2_mean", 
    linewidth=.1,
    scheme=scheme, cmap='inferno_r',
    legend=True,
    edgecolor='black',
    ax=ax
);
ax.set_title('Mean crous rent in french "departements" with residences', fontsize=13)

df_metro.plot(ax = ax, color='green');
# Out:
# /opt/mamba/lib/python3.10/site-packages/geoplot/geoplot.py:982: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for subgeom in geom:

# %% [markdown]
# # Modélisation

# %% [markdown]
# On commence par enlever les NaN du dataframe qui bloquent la regression linéaire

# %%
from sklearn.linear_model import LinearRegression
import math
from sklearn.model_selection import train_test_split

# %%
df.isnull().sum()
df2 = df
index_with_nan = df2.index[df2.isnull().any(axis=1)]
print(index_with_nan.shape)
df2.drop(index_with_nan,0, inplace=True)
df2[['Mean Loyer', 'Mean Surface']].isnull().sum()
# Out:
# (423,)
# /tmp/ipykernel_1182/496102278.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df2.drop(index_with_nan,0, inplace=True)
# Mean Loyer      0
# Mean Surface    0
# dtype: int64

# %%
df2 = df2.reset_index()
df2
# Out:
#      index                                              title  \
# 0        2                       Résidence Les Bas Longchamps
# 1        3                                 Résidence de l’Ile
# 2        5                               Résidence La Fresque
# 3       15                          Résidence Fernand Braudel
# 4       16                           Résidence Portes du Jura
# ..     ...                                                ...
# 360    781              Résidence du Panorama (secteur Rouen)
# 361    782              Résidence Emma Bovary (secteur Rouen)
# 362    783  Cité Grémillon (secteur d'Hérouville-Saint-Clair)
# 363    784                           Résidence Antide Janvier
# 364    785                         Résidence Jean Paul Sartre
#
#                                                  infos  \
# 0    Description Résidence universitaire située à p...
# 1    Description Résidence universitaire située à p...
# 2    Description Résidence universitaire située aux...
# 3    Localisation :\r\n La résidence Fernand Braude...
# 4    Localisation :\r\n A 5 minutes à pied du resto...
# ..                                                 ...
# 360  Localisation\r\n Proche de l'université \r\nDe...
# 361  Localisation\r\n Rouen \r\nDescription\r\n T1 ...
# 362  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 363  Localisation :\r\n Au centre ville, à proximit...
# 364  Localisation :\r\n La résidence Sartre est sit...
#
#                                                address  \
# 0                  2 rue Abraham Lincoln 92220 Bagneux
# 1    14 rue du Docteur Collé - bâtiment 227 du camp...
# 2              10 rue Edmé Bouchardon 78000 Versailles
# 3                  Rue Ernest Duvillard  90016 Belfort
# 4               23 rue Maurice Ravel 25200 Montbéliard
# ..                                                 ...
# 360        Boulevard Siegfried 76130 Mont-Saint-Aignan
# 361                   4 boulevard Gambetta 76000 ROUEN
# 362  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 363                6 rue Antide Janvier 25000 Besançon
# 364                   Rue Gaston Deferre 90000 Belfort
#
#                    geocalisation                  regions  \
# 0     48.7906913757,2.3169708252            Île-de-France
# 1      48.698802948,2.1578958035            Île-de-France
# 2     48.8112220764,2.1460649967            Île-de-France
# 3     47.6403808594,6.8530831337  Bourgogne-Franche-Comté
# 4     47.4966392517,6.8003001213  Bourgogne-Franche-Comté
# ..                           ...                      ...
# 360   49.4621658325,1.0657054186                Normandie
# 361   49.4363975525,1.1012332439                Normandie
# 362  49.2032051086,-0.3392136097                Normandie
# 363   47.2365074158,6.0153431892  Bourgogne-Franche-Comté
# 364   47.6389884949,6.8537139893  Bourgogne-Franche-Comté
#
#                                                  Loyer  Max Loyer  Min Loyer  \
# 0                                       [332.0, 359.0]     359.00     332.00
# 1                                              [362.0]     362.00     362.00
# 2                                       [424.0, 537.0]     537.00     424.00
# 3                         [277.0, 321.0, 427.0, 399.0]     427.00     277.00
# 4                                              [339.0]     339.00     339.00
# ..                                                 ...        ...        ...
# 360         [248.0, 288.0, 315.0, 203.0, 344.0, 430.0]     430.00     203.00
# 361                                     [381.1, 417.7]     417.70     381.10
# 362       [249.85, 312.9, 388.6, 467.4, 525.0, 556.14]     556.14     249.85
# 363                              [347.0, 502.0, 523.0]     523.00     347.00
# 364  [280.0, 311.0, 361.0, 405.0, 416.0, 466.0, 586.0]     586.00     280.00
#
#      Mean Loyer  ...                  LIBGEO   upr.IPm2  \
# 0    345.500000  ...                 Bagneux  24.982816
# 1    362.000000  ...        Bures-sur-Yvette  21.271351
# 2    480.500000  ...              Versailles  28.519253
# 3    356.000000  ...                 Belfort  13.046841
# 4    339.000000  ...             Montbéliard  12.278547
# ..          ...  ...                     ...        ...
# 360  304.666667  ...       Mont-Saint-Aignan  14.845433
# 361  399.400000  ...                   Rouen  14.850004
# 362  416.648333  ...  Hérouville-Saint-Clair  13.705407
# 363  457.333333  ...                Besançon  13.926095
# 364  403.571429  ...                 Belfort  13.046841
#
#                departement                                            Schools  \
# 0           Hauts-de-Seine  [Université Paris Lumières, Université Paris 1...
# 1                  Essonne                          [Université Paris-Saclay]
# 2                 Yvelines  [Université de Versailles Saint-Quentin-en-Yve...
# 3    Territoire-de-Belfort  [Université de technologie de Belfort-Montbéli...
# 4                    Doubs  [Université de technologie de Belfort-Montbéli...
# ..                     ...                                                ...
# 360         Seine-Maritime  [Université de Rouen Normandie, Institut natio...
# 361         Seine-Maritime  [Université de Rouen Normandie, Institut natio...
# 362               Calvados  [École nationale supérieure d'ingénieurs de Ca...
# 363                  Doubs  [Université Bourgogne - Franche-Comté, École n...
# 364  Territoire-de-Belfort  [Université de technologie de Belfort-Montbéli...
#
#                                             Nbstudents  Nbstudents_total  \
# 0    [78, 40413, 15404, 1937, 22246, 422, 52969, 59...            275639
# 1                                              [48595]             48595
# 2                                  [14583, 48595, 305]             63483
# 3                                               [2641]              2641
# 4                                               [2641]              2641
# ..                                                 ...               ...
# 360                                      [34398, 2044]             36442
# 361                                      [34398, 2044]             36442
# 362                                       [845, 32088]             32933
# 363                                 [2077, 779, 23578]             26434
# 364                                             [2641]              2641
#
#     prix_par_m2_min prix_par_m2_max  prix_par_m2_mean comptage_résidence
# 0         11.857143       12.821429         12.339286                  1
# 1         20.111111       20.111111         20.111111                  1
# 2         16.758893       21.225296         18.992095                  1
# 3         14.578947        8.933054         10.595238                  1
# 4         18.833333       18.833333         18.833333                  1
# ..              ...             ...               ...                ...
# 360       22.555556        8.600000         14.585106                  1
# 361       21.172222       19.890476         20.482051                  1
# 362       27.761111        8.060000         10.416208                  1
# 363       18.263158       14.815864         16.844690                  1
# 364       15.555556       11.378641         11.475965                  1
#
# [365 rows x 27 columns]

# %% [markdown]
# Régression linéaire de la moyenne des loyers sur la moyenne des surfaces

# %%
df2['Mean Surface'].describe()
# Out:
# count    365.000000
# mean      22.712599
# std        9.287976
# min        9.000000
# 25%       18.000000
# 50%       21.000000
# 75%       26.666667
# max       88.000000
# Name: Mean Surface, dtype: float64

# %%
var_explicatives = df2['Mean Surface']
YLoyer = df2['Mean Loyer']
#on transforme Y et X en array que l'on reformate
YLoyer = np.array(YLoyer).reshape(-1,1)
var_explicatives = (np.array(var_explicatives).reshape(-1,1))

# %%
X_train, X_test, Y_train, Y_test = train_test_split(var_explicatives,YLoyer,test_size=0.3,train_size=0.7)
lin= LinearRegression()
reg = lin.fit(X_train,Y_train)
pred_train = lin.predict(X_train)
pred_test = lin.predict(X_test)

coefficients_sans_cst= reg.coef_
r_2 = reg.score(X_train,Y_train)
print(r_2)
print(coefficients_sans_cst)
# Out:
# 0.14728724746432353
# [[3.39658429]]

# %%
plt.scatter(X_train, Y_train, color='red') # plotting the observation line
 
plt.plot(X_train, lin.predict(X_train), color='blue') # plotting the regression line
 
plt.title("Loyer moyen vs Surface moyenne (Training set)") # stating the title of the graph
 
plt.xlabel("Surface moyenne") # adding the name of x-axis
plt.ylabel("Loyer moyen") # adding the name of y-axis
plt.show() # specifies end of graph

# %%
#Deuxième essai: regression linéaire du min Loyer sur min surface

# %%
df2[['Min Loyer', 'Min Surface']].isnull().sum()
# Out:
# Min Loyer      0
# Min Surface    0
# dtype: int64

# %%
X_min_surface = df2['Min Surface'] #la variable explicative
Y_min_Loyer = df2['Min Loyer']
#on transforme Y et X en array que l'on reformate
Y_min_Loyer = np.array(Y_min_Loyer).reshape(-1,1)
X_min_surface = (np.array(X_min_surface).reshape(-1,1))

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_min_surface,Y_min_Loyer,test_size=0.2,train_size=0.8)
lin= LinearRegression()
reg = lin.fit(X_train,Y_train)
pred_train = lin.predict(X_train)
pred_test = lin.predict(X_test)

coefficients_sans_cst= reg.coef_
r_2 = reg.score(X_train,Y_train)
print(r_2)
print(coefficients_sans_cst)
# Out:
# 0.05969103068990966
# [[2.63561164]]

# %%
#avec la régression du min Loyer sur min Surface, on a un R² peu significatif

# %%
#Regression linéaire du Loyer sur le nombre total d'étudiants

# %%
df2['Nbstudents_total'].describe()
# Out:
# count       365.000000
# mean      94583.860274
# std      112340.516643
# min           1.000000
# 25%       10652.000000
# 50%       36442.000000
# 75%      110738.000000
# max      323129.000000
# Name: Nbstudents_total, dtype: float64

# %%
X_Nbstudents = df2['Nbstudents_total'] #la variable explicative
YLoyer = df2['Mean Loyer']
#on transforme Y et X en array que l'on reformate
YLoyer = np.array(YLoyer).reshape(-1,1)
X_Nbstudents = (np.array(X_Nbstudents).reshape(-1,1))

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_Nbstudents,YLoyer,test_size=0.2,train_size=0.8)
lin= LinearRegression()
reg = lin.fit(X_train,Y_train)
pred_train = lin.predict(X_train)
pred_test = lin.predict(X_test)

coefficients_sans_cst= reg.coef_
r_2 = reg.score(X_train,Y_train)
print(r_2)
print(coefficients_sans_cst)
# Out:
# 0.2545438942399133
# [[0.00038665]]

# %%
plt.scatter(X_train, Y_train, color='red') # plotting the observation line
 
plt.plot(X_train, lin.predict(X_train), color='blue') # plotting the regression line
 
plt.title("Loyer moyen vs Surface moyenne (Training set)") # stating the title of the graph
 
plt.xlabel("Surface moyenne") # adding the name of x-axis
plt.ylabel("Loyer moyen") # adding the name of y-axis
plt.show() # specifies end of graph

# %%
#Regression linéaire du Loyer sur le LOG du nombre total d'étudiants

# %%
for i in range (0, (np.shape(df2['Nbstudents_total']))[0]): 
    if  df2['Nbstudents_total'][i]==0: 
        df2['Nbstudents_total'][i]=1 #cela permet de ne pas avoir de valeur 0 quand on applique le log
df2['Nbstudents_total'].describe()

len(df2[df2['Nbstudents_total']==0])
# Out:
# /tmp/ipykernel_1182/3281078151.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Nbstudents_total'][i]=1 #cela permet de ne pas avoir de valeur 0 quand on applique le log
# 0

# %%
X_log_Nbstudents = np.log(df2['Nbstudents_total']) #la variable explicative
YLoyer = df2['Mean Loyer']
#on transforme Y et X en array que l'on reformate
YLoyer = np.array(YLoyer).reshape(-1,1)
X_log_Nbstudents = (np.array(X_log_Nbstudents).reshape(-1,1))

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_log_Nbstudents,YLoyer,test_size=0.2,train_size=0.8)
lin= LinearRegression()
reg = lin.fit(X_train,Y_train)
pred_train = lin.predict(X_train)
pred_test = lin.predict(X_test)

coefficients_sans_cst= reg.coef_
r_2 = reg.score(X_train,Y_train)
print(r_2)
print(coefficients_sans_cst)
# Out:
# 0.10523821274587619
# [[6.77162411]]

# %%
df2.columns
# Out:
# Index(['index', 'title', 'infos', 'address', 'geocalisation', 'regions',
#        'Loyer', 'Max Loyer', 'Min Loyer', 'Mean Loyer', 'Surface',
#        'Max Surface', 'Min Surface', 'Mean Surface', 'Longitude', 'Latitude',
#        'geometry', 'LIBGEO', 'upr.IPm2', 'departement', 'Schools',
#        'Nbstudents', 'Nbstudents_total', 'prix_par_m2_min', 'prix_par_m2_max',
#        'prix_par_m2_mean', 'comptage_résidence'],
#       dtype='object')

# %%
#régression linéaire du
