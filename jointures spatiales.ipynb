# %%
import pandas as pd
import nltk
nltk.download('punkt')
import geopandas as gpd
# Out:
# [nltk_data] Downloading package punkt to /home/onyxia/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df_crous = pd.read_csv("df_with_rent_and_surface.csv", sep = ',')

# %%
df_crous = df_crous[ (df_crous["regions"] != "La Réunion") &
                    (df_crous["regions"] != "Guadeloupe") &
                    (df_crous["regions"] != "Martinique") &
                    (df_crous["regions"] != "Guyane")]

# %%
df_crous = df_crous.reset_index(drop = True)

# %%
"""
On récupère les donnés géographiques stockées dans la colonne geocalisation 
qui présente d'abord la latitude puis la longitude. 
"""

Longitude = []
Latitude = []
for j in range(0,df_crous.shape[0]):
    geocalisation = df_crous["geocalisation"][j]
    geocalisation = geocalisation.replace(',', ' ')
    word =  nltk.word_tokenize(geocalisation, language='french')
    Latitude.append(float(word[0]))
    Longitude.append(float(word[1]))
df_crous['Longitude'] = Longitude
df_crous['Latitude'] = Latitude

# %%
df_crous.drop(['geocalisation'], axis = 1, inplace = True)

# %%
df_crous
# Out:
#       id                                              title  \
# 0    205                                   Résidence Vauban
# 1    207                 Résidence Le Square de l'Echiquier
# 2    214                       Résidence Les Bas Longchamps
# 3    225                                 Résidence de l’Ile
# 4    228                             Résidence La Pacaterie
# ..   ...                                                ...
# 759  349  Cité Grémillon (secteur d'Hérouville-Saint-Clair)
# 760  331                           Résidence Antide Janvier
# 761  335                         Résidence Jean Paul Sartre
# 762  416                                              Maret
# 763  420                                          Antipodes
#
#                                         short_desc                     zone  \
# 0                                       Guyancourt                 YVELINES
# 1                                   Cergy-Pontoise               VAL D'OISE
# 2                                          Bagneux           HAUTS DE SEINE
# 3                                 Bures-sur-Yvette                  ESSONNE
# 4                                            Orsay                  ESSONNE
# ..                                             ...                      ...
# 759                                            NaN   Herouville Saint Clair
# 760                    Centre ville, sur les quais  Besançon - Centre ville
# 761                                   Centre ville                  Belfort
# 762  Logements proposés : chambres traditionnelles             DIJON CENTRE
# 763   Logements proposés: appartements du T1 au T3             DIJON CAMPUS
#
#                                                  infos  \
# 0    Description La résidence est située au cœur de...
# 1    DescriptionRésidence universitaire nouvellemen...
# 2    Description Résidence universitaire située à p...
# 3    Description Résidence universitaire située à p...
# 4    Description Résidence universitaire longée par...
# ..                                                 ...
# 759  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 760  Localisation :\r\n Au centre ville, à proximit...
# 761  Localisation :\r\n La résidence Sartre est sit...
# 762                                                NaN
# 763  La résidence compte 350 logements (du T1 au T3...
#
#                                               services  \
# 0    Laverie \r\n  Salles de travail \r\n  Salles d...
# 1    Wifi \r\n   Laverie \r\n  salle de sport \r\n ...
# 2    Laverie \r\n    Salles de travail et de détent...
# 3    Salles de détente, une avec télévision \r\n   ...
# 4    Salles de détente             (télévision, ate...
# ..                                                 ...
# 759                        Gratuits (Sauf € = Payants)
# 760        Wifi Inclus dans le loyerPoint restoParking
# 761                    LaverieParking fermé (15€/mois)
# 762  La Résidence universitaire Maret, située en pl...
# 763  La résidence bénéficie de cabines téléphonique...
#
#                                                contact  \
# 0    Résidence Vauban\r\n 1 boulevard d’Alembert782...
# 1    Résidence Le Square de l'échiquier\n9 square d...
# 2    Résidence de Bagneux /Les Bas de Longchamps\r\...
# 3    Résidence de l’Ile\n14 rue du Docteur Collé - ...
# 4    Résidence La Pacaterie\nBâtiment 499 - rue de ...
# ..                                                 ...
# 759  Cité Grémillon (Secteur d'Hérouville-Saint-Cla...
# 760  Résidence Antide Janvier \r\n 49 T1 et de 27 T...
# 761  Résidence Jean-Paul Sartre \r\n 130 T1, 11 T1 ...
# 762  Résidence MARET \r\n 3 rue du Docteur Maret \r...
# 763  Résidence ANTIPODES \r\n 24/32 rue Alain Savar...
#
#                                                address  \
# 0              1 boulevard d’Alembert 78280 Guyancourt
# 1         9 square de l'échiquier 95800 Cergy-Pontoise
# 2                  2 rue Abraham Lincoln 92220 Bagneux
# 3    14 rue du Docteur Collé - bâtiment 227 du camp...
# 4       Bâtiment 499 - rue de la Pacaterie 91400 Orsay
# ..                                                 ...
# 759  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 760                6 rue Antide Janvier 25000 Besançon
# 761                   Rue Gaston Deferre 90000 Belfort
# 762                3 rue du Docteur Maret  21000 Dijon
# 763                24/32 rue Alain Savary  21000 Dijon
#
#                                             mail  \
# 0           residence.vauban@crous-versailles.fr
# 1          residence.lacroix@crous-versailles.fr
# 2          residence.bagneux@crous-versailles.fr
# 3              residence.ile@crous-versailles.fr
# 4        residence.pacaterie@crous-versailles.fr
# ..                                           ...
# 759                herouville@crous-normandie.fr
# 760  pole-hebergement-besancon@crous-besancon.fr
# 761            pole-hebergement-nfc@crous-bfc.fr
# 762                                          NaN
# 763                                          NaN
#
#                                phone  ...  \
# 0                     01 80 73 04 00  ...
# 1                     01 30 30 38 53  ...
# 2                     01 86 63 00 90  ...
# 3                     01 69 07 68 96  ...
# 4                     01 69 15 75 98  ...
# ..                               ...  ...
# 759                   02 31 47 61 23  ...
# 760                   03 81 48 47 50  ...
# 761  03.84.21.95.37 - 06.48.41.76.36  ...
# 762                   03.45.34.84.57  ...
# 763                   03.45.34.84.81  ...
#
#                                                  Loyer Max Loyer Min Loyer  \
# 0                                       [333.0, 537.0]    537.00    333.00
# 1                                              [334.0]    334.00    334.00
# 2                                       [332.0, 359.0]    359.00    332.00
# 3                                              [362.0]    362.00    362.00
# 4                                              [154.0]    154.00    154.00
# ..                                                 ...       ...       ...
# 759       [249.85, 312.9, 388.6, 467.4, 525.0, 556.14]    556.14    249.85
# 760                              [347.0, 502.0, 523.0]    523.00    347.00
# 761  [280.0, 311.0, 361.0, 405.0, 416.0, 466.0, 586.0]    586.00    280.00
# 762                                                NaN       NaN       NaN
# 763                                                 []       NaN       NaN
#
#      Mean Loyer                              Surface Max Surface Min Surface  \
# 0    435.000000                                   []         NaN         NaN
# 1    334.000000                                   []         NaN         NaN
# 2    345.500000                               [28.0]        28.0        28.0
# 3    362.000000                               [18.0]        18.0        18.0
# 4    154.000000                                   []         NaN         NaN
# ..          ...                                  ...         ...         ...
# 759  416.648333  [9.0, 18.0, 30.0, 49.0, 65.0, 69.0]        69.0         9.0
# 760  457.333333                         [19.0, 35.3]        35.3        19.0
# 761  403.571429                   [18.0, 36.0, 51.5]        51.5        18.0
# 762         NaN                                  NaN         NaN         NaN
# 763         NaN                                   []         NaN         NaN
#
#     Mean Surface Longitude   Latitude
# 0            NaN  2.044151  48.779652
# 1            NaN  2.026887  49.048298
# 2      28.000000  2.316971  48.790691
# 3      18.000000  2.157896  48.698803
# 4            NaN  2.184678  48.701542
# ..           ...       ...        ...
# 759    40.000000 -0.339214  49.203205
# 760    27.150000  6.015343  47.236507
# 761    35.166667  6.853714  47.638988
# 762          NaN  5.035332  47.322498
# 763          NaN  5.072239  47.310177
#
# [764 rows x 28 columns]

# %%
gdf = gpd.GeoDataFrame(
    df_crous, geometry=gpd.points_from_xy(df_crous.Longitude, df_crous.Latitude))

gdf
# Out:
#       id                                              title  \
# 0    205                                   Résidence Vauban
# 1    207                 Résidence Le Square de l'Echiquier
# 2    214                       Résidence Les Bas Longchamps
# 3    225                                 Résidence de l’Ile
# 4    228                             Résidence La Pacaterie
# ..   ...                                                ...
# 759  349  Cité Grémillon (secteur d'Hérouville-Saint-Clair)
# 760  331                           Résidence Antide Janvier
# 761  335                         Résidence Jean Paul Sartre
# 762  416                                              Maret
# 763  420                                          Antipodes
#
#                                         short_desc                     zone  \
# 0                                       Guyancourt                 YVELINES
# 1                                   Cergy-Pontoise               VAL D'OISE
# 2                                          Bagneux           HAUTS DE SEINE
# 3                                 Bures-sur-Yvette                  ESSONNE
# 4                                            Orsay                  ESSONNE
# ..                                             ...                      ...
# 759                                            NaN   Herouville Saint Clair
# 760                    Centre ville, sur les quais  Besançon - Centre ville
# 761                                   Centre ville                  Belfort
# 762  Logements proposés : chambres traditionnelles             DIJON CENTRE
# 763   Logements proposés: appartements du T1 au T3             DIJON CAMPUS
#
#                                                  infos  \
# 0    Description La résidence est située au cœur de...
# 1    DescriptionRésidence universitaire nouvellemen...
# 2    Description Résidence universitaire située à p...
# 3    Description Résidence universitaire située à p...
# 4    Description Résidence universitaire longée par...
# ..                                                 ...
# 759  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 760  Localisation :\r\n Au centre ville, à proximit...
# 761  Localisation :\r\n La résidence Sartre est sit...
# 762                                                NaN
# 763  La résidence compte 350 logements (du T1 au T3...
#
#                                               services  \
# 0    Laverie \r\n  Salles de travail \r\n  Salles d...
# 1    Wifi \r\n   Laverie \r\n  salle de sport \r\n ...
# 2    Laverie \r\n    Salles de travail et de détent...
# 3    Salles de détente, une avec télévision \r\n   ...
# 4    Salles de détente             (télévision, ate...
# ..                                                 ...
# 759                        Gratuits (Sauf € = Payants)
# 760        Wifi Inclus dans le loyerPoint restoParking
# 761                    LaverieParking fermé (15€/mois)
# 762  La Résidence universitaire Maret, située en pl...
# 763  La résidence bénéficie de cabines téléphonique...
#
#                                                contact  \
# 0    Résidence Vauban\r\n 1 boulevard d’Alembert782...
# 1    Résidence Le Square de l'échiquier\n9 square d...
# 2    Résidence de Bagneux /Les Bas de Longchamps\r\...
# 3    Résidence de l’Ile\n14 rue du Docteur Collé - ...
# 4    Résidence La Pacaterie\nBâtiment 499 - rue de ...
# ..                                                 ...
# 759  Cité Grémillon (Secteur d'Hérouville-Saint-Cla...
# 760  Résidence Antide Janvier \r\n 49 T1 et de 27 T...
# 761  Résidence Jean-Paul Sartre \r\n 130 T1, 11 T1 ...
# 762  Résidence MARET \r\n 3 rue du Docteur Maret \r...
# 763  Résidence ANTIPODES \r\n 24/32 rue Alain Savar...
#
#                                                address  \
# 0              1 boulevard d’Alembert 78280 Guyancourt
# 1         9 square de l'échiquier 95800 Cergy-Pontoise
# 2                  2 rue Abraham Lincoln 92220 Bagneux
# 3    14 rue du Docteur Collé - bâtiment 227 du camp...
# 4       Bâtiment 499 - rue de la Pacaterie 91400 Orsay
# ..                                                 ...
# 759  BP 54 - Avenue de la Grande Cavée 14202 Hérouv...
# 760                6 rue Antide Janvier 25000 Besançon
# 761                   Rue Gaston Deferre 90000 Belfort
# 762                3 rue du Docteur Maret  21000 Dijon
# 763                24/32 rue Alain Savary  21000 Dijon
#
#                                             mail  \
# 0           residence.vauban@crous-versailles.fr
# 1          residence.lacroix@crous-versailles.fr
# 2          residence.bagneux@crous-versailles.fr
# 3              residence.ile@crous-versailles.fr
# 4        residence.pacaterie@crous-versailles.fr
# ..                                           ...
# 759                herouville@crous-normandie.fr
# 760  pole-hebergement-besancon@crous-besancon.fr
# 761            pole-hebergement-nfc@crous-bfc.fr
# 762                                          NaN
# 763                                          NaN
#
#                                phone  ... Max Loyer Min Loyer  Mean Loyer  \
# 0                     01 80 73 04 00  ...    537.00    333.00  435.000000
# 1                     01 30 30 38 53  ...    334.00    334.00  334.000000
# 2                     01 86 63 00 90  ...    359.00    332.00  345.500000
# 3                     01 69 07 68 96  ...    362.00    362.00  362.000000
# 4                     01 69 15 75 98  ...    154.00    154.00  154.000000
# ..                               ...  ...       ...       ...         ...
# 759                   02 31 47 61 23  ...    556.14    249.85  416.648333
# 760                   03 81 48 47 50  ...    523.00    347.00  457.333333
# 761  03.84.21.95.37 - 06.48.41.76.36  ...    586.00    280.00  403.571429
# 762                   03.45.34.84.57  ...       NaN       NaN         NaN
# 763                   03.45.34.84.81  ...       NaN       NaN         NaN
#
#                                  Surface Max Surface Min Surface Mean Surface  \
# 0                                     []         NaN         NaN          NaN
# 1                                     []         NaN         NaN          NaN
# 2                                 [28.0]        28.0        28.0    28.000000
# 3                                 [18.0]        18.0        18.0    18.000000
# 4                                     []         NaN         NaN          NaN
# ..                                   ...         ...         ...          ...
# 759  [9.0, 18.0, 30.0, 49.0, 65.0, 69.0]        69.0         9.0    40.000000
# 760                         [19.0, 35.3]        35.3        19.0    27.150000
# 761                   [18.0, 36.0, 51.5]        51.5        18.0    35.166667
# 762                                  NaN         NaN         NaN          NaN
# 763                                   []         NaN         NaN          NaN
#
#     Longitude   Latitude                   geometry
# 0    2.044151  48.779652   POINT (2.04415 48.77965)
# 1    2.026887  49.048298   POINT (2.02689 49.04830)
# 2    2.316971  48.790691   POINT (2.31697 48.79069)
# 3    2.157896  48.698803   POINT (2.15790 48.69880)
# 4    2.184678  48.701542   POINT (2.18468 48.70154)
# ..        ...        ...                        ...
# 759 -0.339214  49.203205  POINT (-0.33921 49.20321)
# 760  6.015343  47.236507   POINT (6.01534 47.23651)
# 761  6.853714  47.638988   POINT (6.85371 47.63899)
# 762  5.035332  47.322498   POINT (5.03533 47.32250)
# 763  5.072239  47.310177   POINT (5.07224 47.31018)
#
# [764 rows x 29 columns]

# %%
gdf = pd.read_csv("loyer_privé.csv")

# %%
gdf
# Out:
#       codgeo     upr.IPm2                                           geometry
# 0      01001  11,85487972  POLYGON ((4.904966116128047 46.16078590428586,...
# 1      01002  11,09535764  POLYGON ((5.404395601608285 46.00777571140739,...
# 2      01004  12,90422511  POLYGON ((5.386373490947654 45.93120621673882,...
# 3      01005  11,85487972  POLYGON ((4.886566579066144 46.01601868476111,...
# 4      01006   11,3222872  POLYGON ((5.5906555306349235 45.75997132496111...
# ...      ...          ...                                                ...
# 34928  97420  12,95850521  POLYGON ((0.3745283084862141 42.20905295992784...
# 34929  97421  12,62690364  POLYGON ((0.3088561146652715 42.10112152757755...
# 34930  97422  13,45103918  POLYGON ((0.1497708865300584 41.79844984974554...
# 34931  97423  17,72006199  POLYGON ((0.0549425032110253 41.95648310451145...
# 34932  97424  17,72006199  POLYGON ((0.0391849509580124 41.92692431725083...
#
# [34933 rows x 3 columns]

# %%
gdf_prive = gpd.GeoDataFrame(gdf)
